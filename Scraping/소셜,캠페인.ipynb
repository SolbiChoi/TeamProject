# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
import requests

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FEC4-11B6
#
#  C:\Develops 디렉터리
#
# 2021-08-12  오후 09:57        11,177,472 chromedriver.exe
#                1개 파일          11,177,472 바이트
#                0개 디렉터리  67,095,777,280 바이트 남음

# %%
driver = webdriver.Chrome()
driver.get('https://www.wadiz.kr/web/wreward/category/295?keyword=&endYn=Y&order=support')

# %%
num_scroll = 15
while num_scroll:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight-1000);")
    time.sleep(2)
    num_scroll -= 1
time.sleep(1)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

browser = webdriver.Chrome('./chromedriver.exe')
data_list = soup.select('div.ProjectCardList_list__1YBa2 > div > div > div > div')
social=[]
for data in data_list:
    title = data.select('strong')[0].text.strip()
    print(title)
    social.append([title])
# Out:
# 소녀를 기억하는 방법. 위안부 소녀상 세우기 캠페인
# 비긴어게인 영철버거 프로젝트
# 유기견보호소 <내사랑바둑이>의 철거와 이사 이야기
# 할머니들께 따뜻한 시선을 돌려드리는 마르코로호 맨투맨, 모자 그리고 팔찌
# #NurwaysWithYOU 이제는 우리가 간호사들을 간호할 차례입니다
# 국내 최초, 월경컵(생리컵) 식약처 허가를 위한 #블랭크컵 프로젝트!
# 카드 한장으로 몰카를 찾는 방법, 몰가드 프로젝트
# 대구/경북에 희망을! Hope Together with 신한
# 음료란 음료는 없습니다.
# 시각장애인과 비장애인이 함께 편견을 딛고 날아오르다, 하람이 나르샤
# 네팔 아이들의 꿈이 담긴 엽서와 에코백
# 故 신해철 '유년의 끝' 기념벤치 Project
# [긴급구호펀딩] 국가 재난 사태 '강원 산불' 구호 펀딩
# 외로운 피그미하마에게 가족을, 피그미하마 연애조작단 To get her
# 생명을 구하는 소방관 아저씨의 손을 지켜주세요
# [같이걸을까] 지적장애인 작가의 작품이 담긴 팔찌
# 2015부산한복데이
# 365명이 직접 손으로 쓴 2015년 달력, 하루를 쓰다
# 캄보디아에 희망의 빛을 밝히는 태양광 랜턴과 태양광 가로등
# 한나네 보호소의 유기견들을 돕기 위한 멍멍이히어로의 프로젝트
# 독도를 가장 가까이에서 만나다. 독도 보틀, 독도 테이블
# 세월호를 기억하기 위한 스마트폰케이스
# 한 달에 한번 찾아오는 '그 날'의 행복찾기!
# 강아지 공장 문제 해결 프로젝트-윤리적 켄넬을 찾기 위해 떠난 100일
# 캄보디아어 캘리그라피가 담긴 다이어리와 에코백은 처음이시죠?
# [카라X언더독] 한 차원 더 나아간 반려동물 복지센터, 카라더봄센터
# 국내최초, 시민이 만드는 동물병원이 개원합니다.
# 청년문제 해결의 공간을 열어주세요 [청년전략스페이스]
# 앞은 보이지 않아도 아픔은 보여요, 시각장애인 심리상담사
# 드림트리 1기 ! 꿈을 나누는 음악으로 캠프를 떠납니다!
# 네팔 대지진 그 후 : 미술심리치료 선물 프로젝트
# ...

# %%
pd_data = pd.DataFrame(social, columns=['wadiz social_campaign'])
pd_data
# Out:
#                         wadiz social_campaign
# 0                소녀를 기억하는 방법. 위안부 소녀상 세우기 캠페인
# 1                             비긴어게인 영철버거 프로젝트
# 2                 유기견보호소 <내사랑바둑이>의 철거와 이사 이야기
# 3    할머니들께 따뜻한 시선을 돌려드리는 마르코로호 맨투맨, 모자 그리고 팔찌
# 4     #NurwaysWithYOU 이제는 우리가 간호사들을 간호할 차례입니다
# ..                                        ...
# 763       [상상지] 방통중 어르신들께 신통방통한 크리스마스를 선물할게요!
# 764                              기부에 디자인을 더하다
# 765                 청소년을 위한 에너지&전기자동차 체험 프로젝트
# 766            네일(Nail)에 봄 & 결혼(Wedding)을 담다.
# 767                       조자용 에밀레 박물관 복원 프로젝트
#
# [768 rows x 1 columns]
