# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
import requests

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FEC4-11B6
#
#  C:\Develops 디렉터리
#
# 2021-08-12  오후 09:57        11,177,472 chromedriver.exe
#                1개 파일          11,177,472 바이트
#                0개 디렉터리  64,594,591,744 바이트 남음

# %%
driver = webdriver.Chrome()
driver.get('https://www.wadiz.kr/web/wreward/category/316?keyword=&endYn=Y&order=support')

# %%
num_scroll = 15
while num_scroll:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight-1000);")
    time.sleep(2)
    num_scroll -= 1
time.sleep(1)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

browser = webdriver.Chrome('./chromedriver.exe')
data_list = soup.select('div.ProjectCardList_list__1YBa2 > div > div > div > div')
Class=[]
for data in data_list:
    title = data.select('strong')[0].text.strip()
    print(title)
    Class.append([title])
# Out:
# [앵콜4.9점] 단계별 영어 원서 : 노인과 바다 (5권이 1권에 쏙~)
# [연세대] 최고의 코딩 교육을 모두에게, 코드잇
# [5차 앵콜] 데이터 사이언스, 알고리즘 강의 with 코드잇
# [6차 앵콜] 내가 좋아서 하는 코딩공부, 코드잇
# [앵콜, 만족도5.0] 영어 원서를 가장 쉽게 읽는 책!
# [코딩 해볼래요?] - 하루 11분, 60일이면 완성하는 파이썬 마스터
# [2312%앵콜 + 4.8만족] IVY 출신이 만든 직장인 10분 영어
# '해외직구쇼핑몰 창업' 이제 누구나 가능합니다.
# D.VIP 시즌2기 멤버십 : 블록체인/암호화폐 투자 네트워킹 사교모임
# 애매한 파닉스! 한글표기 보고 원어민발음 된다면, 영포자는 없을 거예요.
# 퇴근 후 스마트스토어로 월 200만원 벌기! 온라인클래스
# 하루 10분으로 상위1%가 될 수 있는 PPT 온라인클래스!
# 하루 10분, 일러스트에서 굿즈제작까지! 디지털드로잉 온라인클래스
# [하루 20분] 따라하면 됩니다! 아마존 베스트셀러의 잘 파는 노하우
# [월 200 추가 소득] 하루 20분, 누구나 할 수 있는 아마존 셀링
# [5억명사용] 스빡 할사람? 10분 만에 스페인어 빡시게 끝내기!
# 포토샵 온라인 클래스, 하루 10분으로 연봉 2배! 조회수 2배!
# 주식투자? 점심시간 10분으로 주식 마스터! 온라인클래스
# [퇴사X 코인X] 아이디어스&네이버에서 취미로 돈 버는 기술
# [1.2억/만족도 만점 앵콜]돈버는 기술, E-MBA
# 엑셀, 피할 수 없다면 잘하자! (for. 엑셀 무면허인 당신)
# 네이버 없이 떠나자! 더 넓은 세상을 만나는 진짜 여행영어
# 100% 원어민 영어 랭쎄. 올해는 나도 영어 인싸!
# [2.4억달성] 전) CJ 부사장에게 배우는 성공하는 리더 되는 방법
# [500세트 한정]놀면 뭐해? 부담없이 시작하는 진짜 기초 취미미술 앱!
# 틀린 발음으로 아무리 영어 읽기,듣기,말하기 한들, 무슨 소용 있겠어요?
# ...

# %%
pd_data = pd.DataFrame(Class, columns=['wadiz Class'])
pd_data
# Out:
#                                   wadiz Class
# 0    [앵콜4.9점] 단계별 영어 원서 : 노인과 바다 (5권이 1권에 쏙~)
# 1                  [연세대] 최고의 코딩 교육을 모두에게, 코드잇
# 2          [5차 앵콜] 데이터 사이언스, 알고리즘 강의 with 코드잇
# 3                 [6차 앵콜] 내가 좋아서 하는 코딩공부, 코드잇
# 4             [앵콜, 만족도5.0] 영어 원서를 가장 쉽게 읽는 책!
# ..                                        ...
# 310          실전에서 당장 써먹을 수 있는 영어만 배워보세요. 대츠잇!
# 311  하루 5분 취미로 영어 깨자구! 1:1 영어마스터하고 세계여행 준비하자!
# 312            [책만들기 95종 키트] 인디자인 1:1 원데이 클래스
# 313                     N잡러를 위한 라이브커머스 온라인 교육
# 314            (앵콜)분석부터 시각화까지, 매출을 부르는 데이터 분석
#
# [315 rows x 1 columns]
