# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
import requests

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FEC4-11B6
#
#  C:\Develops 디렉터리
#
# 2021-08-12  오후 09:57        11,177,472 chromedriver.exe
#                1개 파일          11,177,472 바이트
#                0개 디렉터리  69,309,698,048 바이트 남음

# %%
driver = webdriver.Chrome()
driver.get('https://www.wadiz.kr/web/wreward/category/311?keyword=&endYn=Y&order=support')

# %%
num_scroll = 15
while num_scroll:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight-1000);")
    time.sleep(2)
    num_scroll -= 1
time.sleep(1)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

browser = webdriver.Chrome('./chromedriver.exe')
data_list = soup.select('div.ProjectCardList_list__1YBa2 > div > div > div > div')
beauty=[]
for data in data_list:
    title = data.select('strong')[0].text.strip()
    print(title)
    beauty.append([title])
# Out:
# 5점 마지막앵콜! 여드름성피부 사용적합임상, 진짜 쎈 진정 <구원세럼>
# Perfume Teller로 찾는 나만의 향기 - 파펨
# [3.6억 앵콜] 와디즈에 <세수한번> 안 써본 사람 없게 해주세요
# [3.7억 메이커] 막걸리장인의 손이 고왔던이유, 갈락토미세스 아우라크림
# 그린토마토, 모공수렴으로 특허받아 화제!
# [5.2억] 와디즈에 <세수한번> 안 써본 사람 없게 해주세요
# [5억/4.8]모공+쿨링+진정 임상특허 21개 샤르드<ICE크림>
# [1억앵콜] 한번에 모공 싹, 장벽 꽉! 평점 만점받은 흑당고가 뭐길래?
# 수분명가 달바ㅣ모공? 가볍게 착붙, 매일 새 것처럼 갈아쓰는 밀착 팩트
# 청담동 1%의 톤과 결. 줄기세포 배양액을 30%나 담은 스피큘 크림.
# [7차 6억 신화] # 미백+수분 폭탄
# [2.6억 앵콜] 그린토마토, 모공특허 임상증명 화제!!
# [5억 | 마지막 앵콜] 모공 쫙~ 장벽 꽉~ 흑당고가 뭐길래?
# [4.9앵콜] 한번만 써도 모공,각질 80% 감소! 임상으로 증명된 링톤
# [1.4억앵콜] 선크림이냐고요? 3초 흡수 비건워터선에센스 입니다.
# <1회 세안으로 모공 대청소> 모공 하나에 티트리 20개가 들어간다면?
# [앵콜] 이미 생성된 멜라닌 색소 분해에 도움을 준다
# 선크림이냐고요? 3초 흡수 선에센스 입니다. | 비건워터 선에센스
# [마지막앵콜] 유리스킨 멜라노크림
# 끈적임 없는 순삭 흡수 여름크림 찾고 계셨죠? 81%진정, 착한성분 참마
# [8035%앵콜] 올인원 블랙헤드 케어! 이건 정말 확실하죠?
# ⭐️5873%앵콜⭐️카모 클렌징패드 사용했더니 모공관리 받냐고 물어보네요
# [6109% 앵콜] 립밤보다 강력한 보습과 영양으로 내 입술 푸딩처럼
# [2억 2천 신화] 다신 없을 모공아웃 #카모패드 + 모공방어 #선크림
# [3억펀딩신화] 멜라닌 색소 분해에 도움을 주는 <멜라노 세럼>
# 개발비용 200억 | 40년만에 탄생한 진짜 EGF 주름개선 기능성 세럼
# ...

# %%
pd_data = pd.DataFrame(beauty, columns=['wadiz beauty'])
pd_data
# Out:
#                                  wadiz beauty
# 0     5점 마지막앵콜! 여드름성피부 사용적합임상, 진짜 쎈 진정 <구원세럼>
# 1              Perfume Teller로 찾는 나만의 향기 - 파펨
# 2       [3.6억 앵콜] 와디즈에 <세수한번> 안 써본 사람 없게 해주세요
# 3    [3.7억 메이커] 막걸리장인의 손이 고왔던이유, 갈락토미세스 아우라크림
# 4                      그린토마토, 모공수렴으로 특허받아 화제!
# ..                                        ...
# 763    [솜사장클렌징패드] 미세먼지세정력 99.9%, 피부보습개선율 104%
# 764               [1억신화/평점4.9앵콜] 미친발색 글리터 섀도우
# 765   [앵콜] 화장품을 싫어하는 대표가 46가지 빼고 만든 고보습 다시마토너
# 766    [업스틱] 뻗친 머리 다운, 처친 머리 볼륨 업, 헤어픽서까지 하나로
# 767  [누적1억신화]후기로 검증된 신개념 "여성청결제" 이너샤인. 냄새안녕!!
#
# [768 rows x 1 columns]
