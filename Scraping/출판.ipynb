# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
import requests

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FEC4-11B6
#
#  C:\Develops 디렉터리
#
# 2021-08-12  오후 09:57        11,177,472 chromedriver.exe
#                1개 파일          11,177,472 바이트
#                0개 디렉터리  70,517,960,704 바이트 남음

# %%
driver = webdriver.Chrome()
driver.get('https://www.wadiz.kr/web/wreward/category/293?keyword=&endYn=Y&order=support')

# %%
num_scroll = 15
while num_scroll:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight-1000);")
    time.sleep(2)
    num_scroll -= 1
time.sleep(1)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

browser = webdriver.Chrome('./chromedriver.exe')
data_list = soup.select('div.ProjectCardList_list__1YBa2 > div > div > div > div')
publication=[]
for data in data_list:
    title = data.select('strong')[0].text.strip()
    print(title)
    publication.append([title])
# Out:
# [앵콜] 만족4.9 영어 원서를 가장 쉽게 읽는 책 (5권이 1권에!)
# 조금 특별한 동물도감, 멸종위기동물 아트북을 소개합니다.
# 누워서 읽는 법학 민사법 시리즈 출판 프로젝트
# [미술관은 못가도 명화는 보고 싶다] 갤러리북 시리즈 3, 클로드 모네
# 1.5억 앵콜ㅣ펼치는 순간 고흐에 빠져들다. 갤러리북 한정판 에디션
# [문화독립운동] 잃어가던 한국화를 되찾다! 한국화시리즈 1, 단원 김홍도
# [미술관] 원화의 감동을 옮기다! 갤러리북 Vol.1 빈센트 반 고흐
# 영포자를 위한 문법책이 찾아왔다! 삼등급부터 구등급까지 모여라!
# [도화지] 강제징용 (강제노역,위안부 등) 책 발간 프로젝트
# [세상 신기한 그림] 반고흐 미술관과 언론도 극찬한 반고흐 명품 명화집
# [당신은 관심없는 독거노인이야기] 출간
# 2시간으로 완전히 끝내는 혁신적인 영어 문법 특급 비밀
# 지역아동센터 아동들을 위한 놀이책 [V-코칭북]
# 누워서 읽는 법학 형사법 편, 공법 편 출판
# [5천만앵콜/4.9만족도] 아이비리거가 만든 직장인 10분 미드 영어회화
# 재기발랄 육군 장교 이야기, ROTC가이드북!
# 책 1권 값에 5권 읽자 <자녀와 함께 읽는 단계별 영어동화>
# 퇴근 후 1분, 아이에게 아빠를 선물하는 아빠놀이 백과사전
# 사실 난 바보가 아니었다. 니들이 영어를 잘못 가르친 거다. [보글리쉬]
# 이제는 끝까지 읽어보자! 이 책이 당신을 끝까지 읽게 해줍니다.
# [구독자 1만 달성] 서울대 출신 전문가들이 직접 쓴 트렌드 상식사전
# 콘텐츠가 리드하는 도시 | 서울편 | 기획자가 주목해야 할 공간들
# 잠든 사이 월급 버는  미국 배당주 투자
# 위기를 기회로 바꾸는 방법 공개! <잠든 사이 부자되는 미국 주식 투자>
# 20대 패션 모델들과 노숙자가 함께 라이프 스타일 잡지를 만들다!
# 아빠를 위한 잡지, [볼드저널] 창간호 발행
# 미국 아이비리그 출신이 만든, 직장인을 위한 10분 미드 회화
# 다가올 미래가치 [회복력] 도서 번역 프로젝트
# [냉정한 여행] 도서출판 프로젝트, 당신은 누구의 눈으로 세상을 봅니까?
# 새하얗게 불태운 [내일의 죠] 완전판 + 프리미엄 굿즈
# 소규모 독립출판 프로젝트, 청춘백화
# <도서 출판 프로젝트>평범한 대학생들이 특별한 청소년들에게 전하는 이야기
# 보기만 해도 1달만에 영어회화 가능한 비밀
# [2차 펀딩] 베스트셀러에 시들해진 그대에게_독립출판물 정기구독 서비스
# 2시간으로 완전히 끝내는 혁신적인 영어문법 특급비밀 #만족도 4.7
# <또다시, 산티아고순례길> 산티아고 순례길, 왜 그렇게 많이 갈까요?
# 옷 잘 입는 남자들의 이야기 , 궁극의 남성 패션을 담은《트루 스타일》
# *3차앵콜* [라이프쉐어 대화카드/다이빙노트] 우리의 대화를 의미 있게
# 언택트 시대, 쉽고 저렴하게 집에서 즐기는 [셀프 플라워 클래스]
# 취업 부스터로 취준생활 빠르게 탈출!!
# 한국식 문법은 그만! 진짜 원어민들이 사용하는 진짜 영문법 500
# 마법 학교의 비밀을 파헤치는 모험이 시작된다! 인터랙션 북, <성도학원>
# 어디에도 없는 DMZ이야기, 매거진 <ABOUT DMZ>
# 평범한 사람들 속에서 가장 빛나는 '나'를 만들어줄 l 패션가이드북 l
# [아빠엄마주목] 성장 다이어리.내 아이에게 줄 수 있는 최고의 선물 !
# [대륙의 중국어] 14억 대륙, 이 책에 담았소이다!
# [앵콜5.0] <누구나 쉽게 읽는 단계별 영어동화>책1권에 5권이 쏙!!
# 교회는 오래 다녔지만 성경을 제대로 읽어 본 적이 없다면?
# 캘리그라피작가가 알려주는 아이패드 활용법, how to procreate
# 작은 책속에 담긴 넓은 부산이야기 : 다시, 부산
# 이야기에 색을 입히다, 조금 특별한 컬러링북 <감>
# 청춘의 기록, 에세이모음집 [말하지 못한 건, 들어주지 않아서]
# 퇴사 직전 | 0원으로 시작한 강사 투잡으로 1억 6천 부수익 벌기 실전
# 함께 피워내는 봄꽃 같은 소설 &lt;얼음새꽃&gt;
# 개인투자자 수익대박을 위한 도서 출판-개수작
# 내 안의 답을 찾는 하루 15분ㅣ좋은 질문들을 엄선한 질문다이어리
# 내 모습을 대변해 줘! 현대인을 위한 아트북 <울랄라 패밀리Vol.1>
# 남들보다 12배 빨리 피아노 작곡 배우는 법
# ​[고생일지 출판 프로젝트] ​무식했기​​에 용감했던 청춘 여행기 ​
# [쏘영닷컴] 중국어가 필요할 땐? 언니에게 물어봐!
# 하루 1만명 방문 블로그가, 돈 버는 법과 성장법 알려드려요.
# 거품 빼기 [보험 초보 가이드북] : 아는 만큼 받는다!
# 영어 독해 상위 1% 시크릿, 영어 문장을 술술 해석하는 노하우!
# 사랑하는 사람과의 대화 해결책, [노크북]
# 사회공헌, 제대로 알고 싶다면? <컨설턴트가 경험한 기업사회공헌>
# 30대 아티스트로 살아가기, Jack Kim's Story
# 질문 다이어리 끝판왕 & 365개의 글귀가 담긴 뜯어쓰는 일력
# [문화독립운동] 잃어가던 한국화를 되찾다! 한국화시리즈 단원 김홍도 앵콜
# 국내 최초의 크라우드펀딩 서적 출판에 직접 참여하세요!
# [Design Like You Give a Damn] 한국어판 출판
# [운동초보,직장인도 할수있는] 3개월 복근만들기 프로젝트
# 네이티브가 생각하는 느낌을 담은 영어 패턴 책
# 스마트스토어 투잡의 모든 것. 구매대행과 병행수입을 한방에! 직장인 부업
# 50페이지로 완성하는 최소한의 인생 재테크, 놀테크
# [우주,화성의 시대]를 내 손으로 열면, 대한민국 청소년들의 꿈이 바뀐다
# 영어회화 유창하게 하는 "3가지 원칙"
# 동네서점들과 함께 만드는 진심의 선물, 도트윈 북마크
# 불황에도 웃습니다, 투자왕 김단테의 "절대수익 투자법칙"
# 낯선 대화로 너와 나를 꺼내보는 "라이프쉐어 대화카드"
# 여행 좋아하세요? 가슴이 뜨거워지는 매거진 ARTRAVEL 아트래블
# [만화복원프로젝트] 마나문고 컴백! 황금날개 시리즈로 출동완료!!
# 초보아빠를 위한 출산선물, 아빠랑 함께하는 공동육아 365
# 진짜 맛있는 샌드위치 만들기! 샌드위치의 기초 X 스마트 저울
# 소셜벤처를 만들고 싶다면? <소셜벤처 창업 핸드북> 출간!
# *4차 앵콜* [라이프쉐어 대화카드/에세이 노트] 우리의 대화를 의미있게
# IDEO HCD Toolkit 한국어판 출판
# [당을 끊는 레시피]를 선물하세요
# 대학의 민낯을 알리는, 검열없는 언론 'N대알리'
# 웹툰<자살소년>단행본 제작 프로젝트
# 심리상담사가 알려주는 반려견과 행복하게 사는 법 (PDF전자책)
# [부업의 정석] 스마트스토어 새내기! 왕초보! 를 위한 상세 가이드북!
# 초딩도 할 수 있는 "기초 영어 해석 꿀팁"
# 잠깐 카페? 오래갈 카페! 100년을 꿈꾸는 동네카페가 책 쓰다 프로젝트
# [슬기로운 창업생활] Start-up Engineering
# 세상에서 가장 재미있는 성경책, 올마이티 바이블
# [사쿤] 도깨비, 인간 세상에 발들이다.
# 스물다섯 청년의 황당한 유라시아 방랑기, 100일만에 10cm
# 하이힐 신고 납품하던 김과장은 어떻게 17개 명함을 가진 CEO가되었을까
# 스티커로 떠나는 로맨틱 무비 여행! <스티커 아트북-로맨스 영화 장소>
# 이런 영어 공부는 처음이야! 스토리로 배우는 미드 영어
# 3억 앵콜ㅣ펼치는 순간 고흐에 빠져들다. 갤러리북 한정판 하드커버 에디션
# 내가 몰랐던 서울, 아날로그 음악생활_LP바 가이드북
# 홍보기사 100만 노출 비결! 혼자하는 언론홍보 실전 가이드 [전자책]
# 나는 안갚는 정부지원금으로 까페 창업했다!
# 비누베이킹
# 플레이북 : 선생님과 학생들이 함께 만드는 플래너
# [재미와 로봇교육을 한번에] 움직이는 페이퍼토이 + 동화책
# 코로나에도 강한 1인 비즈니스 아이템
# <내가 사랑받을 수 없다는 걸 알아> 에세이집 출판 프로젝트
# 나도 통역사가 될 수 있을까
# 스트레스가 풀리는 그림 명상 :  만다라 드로잉 워크북
# 아직도 구매대행만 하니?! 무재고에서 시작해서 직접 수입판매로 스토어운영
# 매일 아침 출근길, 영어원서 완독 프로젝트! 읽고 듣다.
# 그 PPT, 만드는 법
# 퇴근 후 나만의 일을 시작하라 <사이드 허슬러>
# 사장님! 노동법 힘드시죠? <현장에서 바로 통하는 노무 처방전>
# <한국의 SNS 부자들> 비즈니스의 판을 바꾸다!
# 더 클 수 있었다! 우리아이 숨은 5cm찾기 프로젝트<성장백서>
# 남자는 무엇을, 왜 입어야 하는가 <맨 앤 스타일>
# 답답해 죽느니 내가 직접 만드는 SNS콘텐츠
# [이지비엣] 베트남어가 궁금하면? 티나와 배워봐요!
# 너도 셀프 마케팅 할수 있어! <50페이지 브랜딩 마케팅 비법노트>
# <사라지는 것들을 잡다> 사진엽서집 출판 프로젝트
# 나만의 책을 만들고 싶은 모두를 위한 <나의 기록을 한 권의 책으로>
# 사랑에 상처받고 힘들어하는 사람들을 위한 책, <애정결핍 극복>
# [마지막앵콜] 영어 독해의 지름길,  서포터가 인정한 단계별 영어원서
# ★자존감플래너(+이벤트중)★ 나의 행복을 우선하는 100일
# #주식투자비법, 초보자도 주식으로 돈버는 알짜배기 노하우 대방출!
# [1+1기부 프로젝트] 쓰면서 선교하는 성경필사노트,  '말씀을 심다'.
# 베트남 & 인도네시아 주식투자 실전 가이드북
# 부산 서면을 날 것의 시선으로 보는 독립잡지 [날_서면 vol.2]
# 회사에서 체인지메이커로 살아가기-국내 최초 [사내기업가 툴킷] 발간
# 철학 덕후의 지속 가능한 덕질,  <철학 B급 소설 1인 출판 프로젝트>
# 해외취업은 어때? 실감나는 취업비법을 바로 알려줄게요!
# 유니크한 그녀 김정아의 스타트업 인사이트와 재미있는 마케팅 이야기 전자책
# 캘리워크북, 제노붓펜으로 배우는 캘리그라피 with 이니글씨
# 그림이 있는 소설책 <나의 아름다운 고양이 델마> (일러스트 에디션)
# 3차앵콜. 스마트스토어 투잡의 모든 것. 구매대행과 병행수입을 한방에!
# 두번째 공감페이퍼 출간 기념, 이지박스로 소녀들의 건강을 지켜주세요.
# UFO: CIA 극비문서 최초 출간!
# 나로호를 향한 도전, 전국 대학생 로켓연합회의 논문 발간 프로젝트!
# 2017년  버크셔해서웨이 주주총회를 가다
# 베스트셀러가 시들해진 그대에게_독립출판물 정기구독 서비스
# CSR의 미래, 파타고니아에서 찾다! <넥스트 CSR 파타고니아> 출간
# [오디오북] 365일 하루 한편, 이윤지가 낭독하는 베드타임 스토리
# 꼼지맘의 시각장애아동을 위한 점자촉각그림책 만들기
# [물을 거슬러 노를 저어라] 출판 기념 파티
# [경북 군위] 소실마을 할머니 '두려움을 깨고' 문집 발간 프로젝트
# 중학생 취향저격 영어단어책 뮤 (예비중1~예비고1)
# 세상에서 가장 멋진 병밍아웃, '전지적 공황장애 시점' 출판 프로젝트
# 한국을 대표하는 서정시인 정지상 시선
# 컨설턴트도 합격생도 말해주지 않았던 자기소개서 작성 진짜 tip
# 일상창업 - 예비창업자 및 3년 미만 창업자를 위한 안내서
# 차별화된 온라인 모임 만들기와 운영 노하우 꿀팁
# [중국경제 왕홍으로 통通한다] 중국진출, 왕홍도전의 유일한 지침서
# 생각 얽힌 '나' 포트폴리오 직접 만들기
# 내 죽음을 준비할 수 있는 질문이 담긴 다이어리북 - [죽음]문답
# 주식을 차트로 이해하라! 여의도 트레이더의 기술적 분석 - 기초편
# (3차앵콜)하루 1시간. 쿠팡파트너스로 매일 치맥값정도는 벌기_부업 투잡
# 젊은 시각으로 읽는 전통공예 사진에세이집 [손길, 손끝] 출판 프로젝트
# 보통 사람들의 진짜 커리어를 공유합니다.  Mebook
# 500연승 금융투자 프리미엄 교육 eBook(전자책)
# 아내, 노트북을 열다
# [앵콜] 우리의 대화를 깊고 풍성하게 해주는 '라이프쉐어 대화카드'
# 일하는 시간은 줄이고, 돈은 자동으로 따박따박! [돈버는 강점발견]
# 실수없이 좋은 배우자를 고르는 법
# 산만한 아이 마음을 위한 미술 치료 < 내 마음 낙서책 >_산만
# [119REO/기부플래너] 2020년엔 조금 더 특별한,나만의 다이어리!
# [코로나 극복] 위기를 기회로, 단 4장의 카드로 인생을 재설계하라.
# 평범한 내가 책으로 1억 번 비법
# 마음을 담은 문구를 매듭으로 전하세요. [감개매듭 기법 도안 - 기본편]
# 지속 가능한 지구를 지키는 유일한 방법, [쓰레기 사전]
# 하루 1시간. 쿠팡파트너스 + 직접 쿠팡셀러 되기 직장인 부업 투잡
# 마음을 돌보기 시작한 당신을 위한 명상 안내서  [명상하고 앉아있네]
# [6872% 앵콜] 2시간 영문법 특급비밀 + 친절한 왕초보 영어 훈련
# 빈곤을 이해하는 첫걸음, Poverty Simulation 한국어판 제작
# [국내최초]세계를 위한 최고의 기업 비콥소개서  한국어판 출간
# 2017 서울시립대학교 탁상달력
# 갑갑해 하는 우리 아이를 위해 ! 재밌게 놀아요~  슬기로운 육아맘 생활
# 마케팅의 정석 - 4차 산업혁명시대를 위한 마케팅 지침서
# 프로의 인상, 커터 다이어리 | 프로페셔널의 감각적인 비지니스 도구
# ✨괜찮아마을✨서울 말고 지방에 관심 있는 당신을 위한 잡지
# 1인 식품기업으로 비상식적 온라인 유통 트리플 시스템 만들기
# 남장 김종식 화백 (오직 그리다) 12권 전질
# 태국과 동남아의 신학생들에게 '현지어'로 된 전공서적을 제공합니다.
# 성인들을 위한 <취미수학>
# 중국 시장을 이해하는 가장 빠른 방법 - 이커머스 편 리포트
# 일상 속 여행감성 TRAVEL COME TRUE! 컬러링북 마이컬러트립
# 본격 중소기업 인사총무 야생에세이, 오늘의 인사총무 맑음
# 나를 들여다보는 자가심리치유 그림 에세이 <룩인사이드>
# (4차앵콜)하루 1시간. 쿠팡파트너스로 매일 치맥값정도는 벌기_부업 투잡
# 전시를 만드는 사람들의 이야기, '비하인드 예술전시'
# 프랑스 미슐랭 쉐프가 알려주는, 171년 프랑스 명품차 <꼼빠니꼴로니알>
# 뉴욕 월스트리트 헤지펀드 매니저의 프리미엄 실전 주식투자 노하우 교재
# 본격 이슬람 문화여행, 낯설고 신비로운 이슬람, 그리고 두바이!
# 전시를 만드는 사람들의 이야기, '비하인드 예술전시'
# (4차앵콜)하루 1시간. 쿠팡파트너스로 매일 치맥값정도는 벌기_부업 투잡
# 당신의 '아름다움'을 향한 발걸음,5개월 간의 '세계 녹색기업 탐방여행'
# 40개의 대외활동,1억후원 세계일주까지 청춘들을 위한 기술서
# 지구에서 태어날 모든 아기를 위한 친환경 그림책 <평화로운 탄생> 출판
# 세계 100대 명화 X 동주, 소월, 용운, 영랑의 글
# 아이들을 위한 여행 동화 팝업북 - 수원편
# 디자이너 선배가 알려주는 인쇄꿀팁
# 연봉 1억 마케터의  이직&업무
# 99% 성공하는 내 집 짓기!  <시골땅 집짓기 성공해부학>
# [리워드펀딩, 이것만 보세요] 와디즈가 알려주지 않는 꿀TIP 대방출
# [K마켓 상위 1%] 전자책 2000만원 노하우
# [한글이나르샤] 소리와 글자로 쉽게 익히는 우리아이 첫 한글책!
# 더 나은 프로젝트를 위한 전문가들의 <프로젝트 매니지먼트 DIY 툴킷>
# 당신이 잊고 있었거나, 미처 하지 못했던 생각 NEWWIT [정기구독]
# 인싸아싸 다 모여라! 인싸들의 마술책
# 디자이너를 위한 무료사이트 모음 / SNS 활용에 꼭필요한 자료
# 서클로 마음을 연결하고 싶은 가족을 위한 "가족서클"
# [월 5000만원 매출 인증] 1시간 속성, 돈 버는 스마트스토어
# [앵콜] [부업의 정석] 스마트스토어 왕초보! 를 위한 상세 가이드북!
# 아이와 부모가 함께하는 여행스케치
# <인사이트 디스커버리 프로젝트>와 함께 트렌드의 바다를 항해하세요
# 카톡을 내 앱처럼 만들어서 온라인 마케팅 전쟁에서 승리하기
# 첫 번째 계절 이야기, 여름 : [여름의 캐럴] 소장본 제작
# 프리랜서 예술강사 1인 창업 가이드북
# 앵콜펀딩: 원어민과 재미있게 영어공부하기 1 (Eva 선생님편)
# 4차앵콜.스마트스토어 투잡의 모든 것. 구매대행과 병행수입을 한방에!
# [감성출판프로젝트]시와 사진_너라는 의미 너라는 위로
# 장애인 문학동아리의 창작동화 출판기, 어린이들에게 꿈을 선물합니다
# 과학기술로 세상을 바꾸고 싶은 사람들 vol. 1
# 백소영의 <드라마속 윤(倫), 리(理)> 출판, 토크 콘서트 프로젝트
# 기적을기억하다, 소설<태안>과 캠페인에코백
# 세 달의 기적, 습관은 눈덩이처럼
# 3만원에 30조의 상업용 부동산정보를! TOP45 서울 오피스빌딩 매거진
# 2초만에 영어가 튀어나온다, '직장인 3개월 영어 프리토킹'
# [싱가포르의 기적] 글로벌 도시국가 싱가포르
# 히데코의 사계절 술안주 X 은곡도마
# 심리상담 워크북, 자가치유를 위한 마음처치 매뉴얼
# 합격포인트 콕콕 짚어주는 핵심꿀팁 실전서! 나도 찐 피부미용사
# [ 영한 대역 에세이] 생각하는 번역가의 자유로운 사색
# 당신이 주식투자로 돈을 잃는 5가지이유
# 공대생, 영포자들을 위한 기초영어기본서, 공대생 영어
# 내가 좋으면 그만인데! 책 <알 바야 쓰레빠야>
# 퍼스널브랜딩 전문가가 만든 콘텐츠 기획 실전 노하우
# 김유정소설을 활판인쇄본으로 소장하기
# 당신이 주식투자로 돈을 잃는 5가지이유
# 공대생, 영포자들을 위한 기초영어기본서, 공대생 영어
# 저성장시대의 혁신 방법, [검소한 이노베이션] 한국어판 출간
# 새해엔 나도 CEO '아빠, 나 창업할래' 출판 프로젝트
# 디지털 마케팅 개론 도서 - 4차 산업혁명 시대의 마케팅 가이드
# 120일간 150곳, 세계 녹색기업들을 만난 탐방모험기
# [로스터스뮤직] 당신의 이야기를 담은 음악 M.I.C
# 빅데이터로 보는 미국주식 투자지도 2021
# 12명의 한달사용금액에 따라 최대혜택받는 신용체크카드 추천설계서 <카밋>
# [TOOLKIT] 마음과 행동을 기획하는 비즈니스 툴킷
# [재테크의 본질 3요소]  부의 트라이앵글
# 인간관계에 지친 당신을 위한 세상에 하나뿐인 질문북 ‘I AM’
# 조각조각 내 손으로 채워가는 우리의 멋! 스티커 컬러링북 [조선왕실 편]
# 개발자에게 쉽게 배우자! 데이터 사이언스부터 머신러닝까지
# 한 권으로 끝내는  '내 생에 첫 번째 책 쓰기'
# 나만의 손글씨 굿즈 만들기, EASY 캘리그라피
# 마음을 다스리는 동양철학의 힘, <주체적으로 산다>
# 알고 마시면 더 맛있는 한 잔, <맥주도 취미가 될 수 있나요?>
# 나는 인디고 아이다
# 면접 STAR 카드
# 누워서 읽는 법학 [민사법] 2판 제작, [형사법], [공법] 편 구매
# 당신의 마음을 전달하는 방법, [따뜻한 책] 출판 프로젝트
# 암호화폐의 미래를 보여주는 이해하기 쉽고 재미있는 크립토이야기
# 진짜 맛집은 어디에 있을까요? [블루북]으로 맛집탐방 고민 끝!
# 건축유영술을 고민하는 돈키호테 그를 위한 건축안내서-아카이브프로젝트 더북
# 누구나 한번쯤은 꿈꿔봤을 길 위의 나의 집《밴 라이프》출판 프로젝트
# OO살에 연봉 1.5억 한국인 아들이 자란 방법? 전자책 최초공개!
# [호캉스 어디가지?] 호텔에 천만원 넘게 쓴 호텔리뷰어의 호텔 가이드북
# 가방 디자이너가 알아야 할 기본 지식+기술 8가지 - 속성 입문 가이드
# 손기정평전-오팔세대와 밀레니얼세대가 함께 하는 회환의 손기정 열전 마라톤
# 결혼은 하는 것보다 유지하는 것이 더 어렵다
# MD로 살고 있습니다 (예비 상품기획자 & 취준생 길라잡이)
# 각인되고 싶은 당신을 위한 브랜딩블로그 디자인 방법론!
# 서울, 일상속 무지개색 여행, I.SEOUL.U 7 드로잉북
# 팬데믹으로 인한 교육의 변화와 미래 <교사 난중일기: 팬데믹의 교사들>
# 파워풀한 삶을 위한 로드맵
# 상처란 치유되고 있다는 증거다
# 김대중, 정치인 이전에 청년 민족사업가로서의 삶을 그린 청년사업가 김대중
# 검소하고 유연한 혁신방법, [주가드이노베이션] 한국어판 출간
# 함께 마음껏색칠, 신개념 컬러 놀이「틴코」
# 미국주식S&P500가이드북
# [소자본창업 강의] 8천원으로 정복하기!! 입문자전용 E-Book
# '우리 몸을 망치는 Vicious cycle' PDF책 출판
# 네이버 블로그 하루 1만명을 만들 수 있었던 노하우와 매출로 연결시키는법
# 손세차부터 셀프광택까지 자동차 디테일링의 모든 것 <세차의 정석>
# [앵콜 펀딩] 그 PPT, 만드는 법(개정판)
# 지금 당신의 미션은 무엇입니까?
# 내비게이션 기억법
# 지금 당신의 미션은 무엇입니까?
# [앵콜 펀딩] 그 PPT, 만드는 법(개정판)
# 416% 3차 앵콜ㅣ한달만에 영어회화가 되는 비밀ㅣ영어회화 자동암기
# 부업의 모든것. 쿠팡파트너스, 스마트 스토어, 구매대행, 해외사입(수입)
# 당신의 꿈과 이야기를 모아 책을 만듭니다 : 이어드림
# 일상에서 예술하실래요? 떠오를 잡지 [서툰]
# [종교개혁 500주년 기념] 맥아더성경주석으로 스터디바이블 만들기
# 상상력이 쑥쑥 자라나는 한글그림책   [고마워, 한글도깨비야]
# [ 150일간의 세계 녹색기업/시장 탐방조사여행 ]
# <천가시千家詩> 한 권으로 끝내는 중국 한시
# 그림책 <이 땅의 비밀> 세상에서 가장 큰 퍼즐! 지구땅에 숨겨진 이야기
# 부동산으로 번 돈, 이제는 지킬 차례! 땅배기의 부동산 세금 일당백하기!
# 언택트시대에서 성공적인 블로그 직접 운영하기, 만블이 알려드려요.
# [대면 취업컨설팅 핵심을 한 권의 책으로] 취업전쟁 승자는 있다
# [180조 시장]중소기업을 위한 시장, 공공입찰(나라장터) 뽀개기
# [세대차이?세대공감] 자기개발서NO! 소통개발서, 보기드문잡지 NO.X
# 감각을 열어야 들리는 물고기 마지막 말 <해양동물 아트 북>
# n개의 문장 : 소규모 교환 에세이집 프로젝트 [Theme : 여행]
# 고승님을 향한 나의 마음 여행기
# 나도 반주할 수 있다 버클리음대 출신 교수진이 집필한 피아노 반주법 교재
# 꿈을 고민할 기회를 주세요. <MeBook_스페셜리스트>
# 세계 영화 장인 112명의 노트와 인터뷰, '필름크래프트'
# 잘나가는 크리에이터의 발상법! 미래 인사이트 종합본 <디자인 매니페스토>
# 혼자여도, 함께여도 좋은 감성충만 맥주&와인 페어링 박스
# 세상에 하나 뿐인 순간의 기록, '어떤 날은 영화처럼, 필름북'
# [앵콜] 1+1 기부프로젝트_쓰면서 선교하는 필사노트, "말씀을 심다.
# 매콤살벌 핏빛 떡볶이 액션 요리 <복희의 레시피>
# 본업 + 부업 두 마리 토끼 잡는 법
# 내 마음을 돌보는 심리도구, 열기카드
# 비즈니스모델을 혁신하는 5가지의 길 - 5 Innovation ways
# [프랜차이즈 음식점] 창업이 처음인 당신을 위해, 성공창업 지침서.
# 단 두권으로 영어회화 끝내기!
# 보다 나은 삶을 위한 목표관리 도구 - 석세스플래너 2018
# 매일 반복되는 직장생활에 현타온다면? 멘탈 붙들어줄 나나나학습지
# 출근만 하는 재미없는 일상에서 벗어나고 싶다면, <딴짓매거진>
# <오늘이 내 인생의 봄날입니다>도서출간에 힘을 보태주세요
# 500연승 금융투자 교육 맛보기
# 국내 최초 미국주식 퀀트분석 서비스 뉴지랭크US
# 수학문제 해설을 동영상으로!
# 60년을 넘어 100년으로 | <오브젝트의 사물_피스코리아> 브랜드북
# [자기계발서] 후회없이 일 하는 방법, 몰입의 Know-How
# 행복한 가사 분담을 위한, 가사분담 굿 가이드북
# 감동전할 준비되셨나요? 커플,프로포즈,결혼기념 특별한선물 크리스마스전배송
# 왕초보 영어 전문가가 만든, 한국인이 자주 틀리는 왕초보 영어 100
# 부부사이가 나빠지면 어쩌죠? 걱정마세요, 20년간 검증된 백신이 있어요!
# 하루 1시간. 쿠팡파트너스로 매일 치맥값정도는 벌기_직장인 부업 투잡
# 좋아하는 꽃을 즐기며 창업에 도전해 보세요. 플로리스트 1인 창업
# 총 구독자 300만 유튜버에게 배우는 전세계 대상으로 유튜브에서 돈버는법
# 하루 1시간. 쿠팡파트너스로 매일 치맥값정도는 벌기_직장인 부업 투잡
# 좋아하는 꽃을 즐기며 창업에 도전해 보세요. 플로리스트 1인 창업
# 총 구독자 300만 유튜버에게 배우는 전세계 대상으로 유튜브에서 돈버는법
# (영문법) GRAMMAR  MASTER  +
# 자동차매니아를 위한 2015서울모터쇼 화보집 출판
# 읽기 쉬운 만화성경, [올마이티바이블 사도행전] 편 프로젝트
# 대한민국 영어를 고발합니다! 우리 동생, 후배, 아들, 딸의 행복 위해서
# 엄마,아빠 우리 공룡 보러가요! 18개 명소를 담은 '대한민국 공룡탐험'
# 나만의 맞춤 진학 (나만을 위한 고등학교 자소서)
# [취업] 평범한 스펙만으로 매력적인 자소서 작성하기 가이드북
# 광고인을 꿈꾸는 이들을 위한 REAL 광고회사 합격 가이드
# 꽃 한 편[꽃:단편] - 꽃말과 목소리가 담긴 '들리는 책'을 선물하세요
# 출판 편집자가 공개하는 전자책 제작의 모든 노하우
# 크리스마스 트리가 된 루돌프
# 이탈리아 와인여행
# (5차앵콜)하루 1시간. 쿠팡파트너스로 매일 치맥값정도는 벌기_부업 투잡
# [세상에서 가장 아름다운 인형의 비밀]X움직이는 종이 인형
# 2020년 대세 투잡, 전자책 종이책 출판과 신개념 투잡까지 싹쓰리!
# [취준생+이직준비생 필독] 2시간 만에 면접의 신이 되는 합격 백서
# 온라인 멘토링으로 나만의 경험과 노하우를 수익화 하는법
# 남겨진 사람의 일기 <여백의 미 공백의 슬픔> 독립 출판 프로젝트
# 아무도 나에게 좋아한다고 말하지 말아 줘, <오렌지칵테일>
# 스토리로 배우는 미드 영어 회화, 자막 없이 미드 보기 상상을 현실로!
# 무대 뒤로 사라지는 흑백사진을 감광지에 옮기다. 마애불(磨崖佛)
# 불교를 다룬 만화, 케이툰 완결 <화작작 조남남>그래픽노블 출간 프로젝트
# 성공보다 실패가 더 많은 스타트업 이야기
# 운영비 0원! 무재고! 무배송! 하루 2시간! 스마트스토어로 월200벌기
# 유튜브는 처음입니다만 -  예비 유튜버를 위한 10가지 유튜브 성공 전략
# DIY마케팅자동화 - 1인기업 디비수집부터 홍보까지 마케팅자동화 비법공개
# [1,000만 성도의 꿈]나만의 평생 예배스토리를 만들다, 생활예배노트
# 성경말씀카드 | 좋은 성경 구절이 당신에게 힘이되길
# 엄마가 새겨주는 후천적 부자 DNA
# <두 번째 밤에 만나는 종이 없는 수필> 잠들기 전, 가장 서정적인 시간
# [취업을 성공으로 이끄는 전략 도우미 ] 성공취업과 전략
# 사랑도, 헤어짐도 연습할 수 있다면 : [울지 말아요, 연습인데]
# 최경일쌤의 컬러링북 시즌2
# 스타벅스를 통해 보는 4차산업 혁명의 미래, 마케팅 트렌드의 모든 것!
# [앵콜] 책만들기 100종 키트 - 인디자인 원데이 클래스
# 길엔터테인먼트의 어른동화, 인형의 별을 함께 만들어주세요
# 웹툰과 광고를 통한 노숙인 인식 개선: 전문가를 모십니다
# Take out My Sexy Book 두 번째 출간 프로젝트
# 어른들이 더 좋아하는 올마이티 바이블, 첫 번째 구약서 [출애굽기]
# 즐거운 실험으로 깨우치는 재미있는 CQ과학
# 당신의 책이 여행을 떠나려 합니다 RE : BOOKS
# [전국민 필독서] 우리말이 중국어로 바뀌는 신비의 여행 : 천지인 중국어
# 상상이 현실로... 우리아이가 동화책속으로 들어왔다
# 디저트 좋아하세요? 당신을 위한 [감성 디저트 맛집 완벽 가이드]
# 전문가가 알려주는 머신러닝, 딥러닝 Computer Vision 마스터
# K-콘텐츠 퓨전 역사소설  < 춤추는 왕자님, 별을 쏘다>
# 수능에 나올 지문만! 수능 영어 연계교재 The final 204제
# 색과 도형으로 보는 너와 나의 심리이야기<오로라심리카드>
# 다가올 가을, 당신의 브런치 일상을 바꿔줄 맛집 탐방 프로젝트
# 후와유 마림바 리듬편
# 불투명한 미래를 어떻게 예측하고 대비할 것인가?
# [바이오필릭 시티] 자연을 품은 지속가능한 도시 모델
# 디저트 좋아하세요? 당신을 위한 [감성 디저트 맛집 완벽 가이드]
# 북한, 어디까지 가봤니? 어디까지 알고있니?
# 전문가가 알려주는 머신러닝, 딥러닝 Computer Vision 마스터
# 초보도 월 100만원 가능한 블로그 마케팅!  쿠팡파트너스로 시작합니다!
# [인싸담당자] 직무인터북: 현직자 인터뷰로 직무이해 대신 끝내줄게요!
# 어른들이 더 좋아하는 만화성경책, 올마이티 바이블 누가복음!
# <여리고에서 배우는 재정관리, 샬롬재테크>  출판 프로젝트
# 다윗과 사무엘을 만나는 올마이티 바이블 [사무엘상]
# 논리적 사고력을 키워주는 수학, 유클리드 기하학원론 워크북
# 미국 주식 분야 1등! <왕초보도 돈 버는 글로벌 투자 원포인트 레슨>
# 펀딩성공, <한방명의의 길을 묻다> 다양한 리워드혜택
# 1919유관순과 그녀들의 조국
# 나도 이제 'BAR- 홈텐더' 집에서 만드는 홈테일, 칵테일
# 나 자신을 발견해 나가는 여정이 담긴 작은 책, 그리고 퍼즐
# SQL과 구글시트로 시작하는 데이터 분석
# 똥손도 할 수 있는 소자본 핸드메이드 창업
# 원어민과 재미있게 영어공부하기
# 9년 연애와 결혼, 당신의 연애세포를 일하게 만드는 글
# [인터뷰집] 한국 출신 해외입양인이 들려주는 나를 찾아가는 이야기
# 창업을 원한다면, 팀 드레이퍼의《스타트업 히어로》를 만나보세요.
# 디지털 마케팅 맞춤 VOD 강의와 eBook, 이 모든 것을 한 번에!
# 나무의 발자국 또다른 나의 우주 <LEAF>
# 중딩수학으로 뽀개는 당구 3쿠션 Angle System
# 5차앵콜.스마트스토어 투잡의 모든 것. 구매대행과 병행수입을 한방에!
# 문화예술산업 종사자들의 인터뷰 모음집, Artist Testify
# 스쳐간 것들에 대한 7개의 시선. 그리고 사진집.
# 500만 주식투자자를 위한 창조적 공감
# [출판］향토음식으로 푼 남녀생활 교감 에피소드, 음식男女 상열심사
# 나만의 책 ......누구나 부담없는 소량(30권) 출판 프로젝트
# 중국 시장을 이해하는 가장 빠른 방법 - 미디어 마케팅 편 리포트
# 미국주식투자, 워런 버핏에게 길을 묻다
# 90세에 문인의 삶 찾아나선 할머니 <90세의 꿈>
# 당신의 제품엔 브랜딩이 필요하다! 브랜딩 지침서 <브랜딩 고유감각>
# 저항의 아이콘, "가이 포크스" 원작소설
# 한달에 한번. 세상 단 하나뿐인  청춘작가의 글을 보내는 '모모레터'
# 세상에서 제일 재미있는 성경책, 올마이티바이블 창세기
# 수학과 코딩교육을 동시에 ! 메타코딩 수학
# 전자책 만들기 전에 꼭 알아야 하는 상표
# 여자의 영원한 로망, 다이아몬드. 청담동매니저의 다이아몬드 꿀팁 대공개!
# 면접으로 직행하는 자기소개서 작성법!
# 한 번 뿐인 인생, 나를 위한 선물. 나를 찾아 책 속으로 떠나는 여행.
# 쇼핑몰운영10년 경험을 바탕으로 쇼핑몰 매출올리는 실전 테크트리
# 빅5 출신 간호사 작가가 쓴 '간호사 자소서 공략집'
# [ 아돼삼AR ] 당신이 몰랐던 아기돼지 삼형제의 결말, 지금 시작됩니다
# [나도 이제 1인 기업!] 블로그 마케팅 비밀 노하우
# 책의 몸을 즐기는 법
# 나의 사십대 이야기 (여행, 요리, 나의 생각들)
# 최승윤 작가의 두번째 그림책을 소장하세요
# Daum 웹툰  -무장-  주인공 권 피규어 출시
# 세상에서 가장 재미있는 성경책, 올마이티바이블 - 요한계시록편
# 읽기 쉬운 만화성경 올마이티바이블[사무엘하]
# <위대한 생명>을 통해 누구나 즉각 이뤄지는 행복 만들기
# 삶을 가치 있게 만드는 내 안의 멀리 뛰기, <원ONE> 출판 프로젝트
# 삼성, 익숙한 것과의 결별. 희망퇴직
# 직접 짓는 전원주택. 전세금으로 주택을 소유한 실제 작가리포트
# 꿈을 실현시키는 청년의 '150일간의 세계 녹색기업/시장 탐방조사여행'
# 하루 9분의 마법 ~75% 이상 할인된 영어 학습 끝판왕 애니톡
# 30분만에 주식 초보 탈출하기
# 우리들의 이야기 "스토리 플립북"
# 4차원 가치탐색형 인간
# 파워풀한 삶을위한 로드맵 전자책 출간
# [건강한 취미생활/치매예방/부모님 선물] 꽃 수채화 증강현실 AR컬러링북
# [서버가 펑!]매출도 수익도 포기할 수 없을 때, 종합감기약 '프로모션'
# 영어를 잘하고 싶은 당신과 함께 나누고 싶은 이야기
# 죽음을 통해 우리의 '진짜'를 찾습니다. 미리쓰는 유언장 출판 프로젝트
# 4계절을 품은 포항, 사진집 '더포항' 출판
# 원어민영어 듣고,말하기위한 [영어 뽀개보기®_나랏말싸미로]출판
# 이미지 파워 : 세상을 보는 안목을 높여주는 자기계발서
# 2016 제3회 청소년독서토론대회
# [공부예찬] 100+100 책 기부 프로젝트
# 우리 아이의 진심을 들여다보는 방법, 작문프로파일링 책 출판 크라우드펀딩
# 세상에서 가장 재미있는 성격책 올마이티바이블 - 다니엘서
# '신화적 명제'로 쓴 시와 미술평론 <예술의 명제>
# 1+1 고전읽기 시리즈 2권(군주론, 리바이어던)
# 29세 신채호저 '을지문덕' 재출판!!
# 4차 산업혁명, 미래를 향해 현재의 교육을 디자인하다!
# 북한땅 트레킹(경제특구,개발구 중심으로)
# 명화 감상 목에 힘주고 보기(지인 ,애인 앞에서 핵심 지식으로 뽐내기)
# 카피 한 줄로 직장 폐인들을 위로하는 <카폐인>
# 세상에서 가장 재미있는 성경책 올마아티바이블 - 여호수아사사기
# 언제든지 누구든지 어디서든지 길을 얻는 창업 네비게이션
# 우리 옆 동네는 얼마일까요? [전국 아파트 시세 지도]
# 매일 밤, 퇴근 후 3분공감 <언젠가 그리울 오늘>
# 자녀교육을 위한 부모수업
# 소자본창업 네일샵 가이드북
# 엄마와 딸이 함께 쓴 전자책 <종이로 만드는 나의 미술관>에 초대합니다
# 나 그리고 나의 자녀는 안녕하신가요? [자존감스쿨]
# [디자인 병법 27계] 자신의 상품을 멋지게 디자인할 수 있다.
# [출판 프로젝트] 빅데이터 시대를 미리 준비하는 당신을 위한 안내서
# 자기소개서 고민이 없는 세상을 꿈꾸다. 속시원한 자소서 첨삭 프로젝트!!
# 베르테르는 더 이상 죽지 않는다, 개정판을 만듭니다
# 2016 올킬 자기소개서 실전합격 20편 출간
# 광고/홍보/웨딩/파티/이벤트 등 각종 영상 제작
# 독하게 공부하는, 독한 국어 시리즈; SAT, LEET+PSAT+SSAT
# 모르면 5,000만원 손해보는 '무료자원'
# [소설] 시인, 조폭 - 시인은 왜 조폭이 될 수 밖에 없었나
# 우리들이 꼭 알아야 할 노동법, 퇴직금 받기 한 달 전 해고되었다
# 2018년 한해를 되돌아 보는 2019년 한국보도사진전 달력
# 반려동물 죽음에 대한 우리의 자세. 반려동물 "감성에세이"
# "김코치 영업" 당신도 영업으로 성공할 수 있다.
# 세상에서 가장 쉬운 철학책_플라톤
# 창작자를 위한 일러스트,원화,만화,캐릭터,이미지 뱅크 구축 프로젝트
# [슬기로운 불안 관리] 퇴근 후, 내 마음의 안정을 찾는 시간
# 우리엄마도 대학생아들도 할 수 있는 쉬운 주식 배우기!!
# 책 한권으로 포토샵 독학이 가능합니다
# 프로 제작자가 알려주는 500개의 굿즈 제조 업체와 노하우

# %%
pd_data = pd.DataFrame(publication, columns=['wadiz publication'])
pd_data
# Out:
#                            wadiz publication
# 0    [앵콜] 만족4.9 영어 원서를 가장 쉽게 읽는 책 (5권이 1권에!)
# 1            조금 특별한 동물도감, 멸종위기동물 아트북을 소개합니다.
# 2                  누워서 읽는 법학 민사법 시리즈 출판 프로젝트
# 3    [미술관은 못가도 명화는 보고 싶다] 갤러리북 시리즈 3, 클로드 모네
# 4      1.5억 앵콜ㅣ펼치는 순간 고흐에 빠져들다. 갤러리북 한정판 에디션
# ..                                       ...
# 492    창작자를 위한 일러스트,원화,만화,캐릭터,이미지 뱅크 구축 프로젝트
# 493       [슬기로운 불안 관리] 퇴근 후, 내 마음의 안정을 찾는 시간
# 494          우리엄마도 대학생아들도 할 수 있는 쉬운 주식 배우기!!
# 495                     책 한권으로 포토샵 독학이 가능합니다
# 496         프로 제작자가 알려주는 500개의 굿즈 제조 업체와 노하우
#
# [497 rows x 1 columns]
