# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
import requests

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FEC4-11B6
#
#  C:\Develops 디렉터리
#
# 2021-08-12  오후 09:57        11,177,472 chromedriver.exe
#                1개 파일          11,177,472 바이트
#                0개 디렉터리  67,014,004,736 바이트 남음

# %%
driver = webdriver.Chrome()
driver.get('https://www.wadiz.kr/web/wreward/category/297?keyword=&endYn=Y&order=support')

# %%
num_scroll = 15
while num_scroll:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight-1000);")
    time.sleep(2)
    num_scroll -= 1
time.sleep(1)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

browser = webdriver.Chrome('./chromedriver.exe')
data_list = soup.select('div.ProjectCardList_list__1YBa2 > div > div > div > div')
sport=[]
for data in data_list:
    title = data.select('strong')[0].text.strip()
    print(title)
    sport.append([title])
# Out:
# 세계최초의 폴딩형 역삼륜 전동킥보드 - TRANSBOARD
# [글로벌 5억] 100년간 변하지 않은 와이퍼의 혁신ㅣ킴블레이드
# 튼튼한 고정력, 넉넉한 수납력에 무선충전까지! 차량용 클로버 멀티 컵홀더
# [2억 앵콜] 100년간 변하지 않은 자동차 와이퍼의 혁신ㅣ킴블레이드
# [1+1이벤트] 무게와 가격 부담을 동시에 잡은 전동킥보드!
# [골프존] 리얼한 타격, 짜릿한 손맛! 집에서 즐기는 진짜 골프, 비전홈
# [퍼팅공포탈출!] 인공지능 로봇개발회사가 만든 디지털 퍼팅연습기
# 가격, 디자인, 품질을 모두 잡은 국민 전동킥보드, 아이로드 i6
# 답답한 허리, 파스로도 해결이 안 되면 전문가가 개발한 룸바냅이 정답!
# <웨이트도 홈트로 끝내자> 9만 원대에 만나는 나만의 헬스장, 머슬레인
# 속 시원한 분사력 전동 분무기! 이 맛에 셀프 세차한다!
# <13,000원으로 새 차 만들기> 흠집/발수/광택/세정까지! #쇼킹젤
# 목디스크 걸린 물리치료사가 작정하고 만든 차량용 목쿠션, 허리쿠션
# 한 병 7,900원으로 엔진을 새것처럼 바꿔주는 마법! | 연료첨가제
# 500만원짜리 필라테스 기구를 9만원으로 내방에! 2020 홈트 끝판왕
# 한번더! 올겨울 88,000원으로  더 따뜻하게, 스켈리도 롱패딩
# [2억앵콜]답답한 허리, 파스도 답이 없다면 전문가 손길 룸바냅이 정답!
# [10억 달성 마지막 앵콜] 다가오는 장마, 자동차 와이퍼는 킴블레이드!
# 헌차를 새차로, 자동차 잔기스를 슥슥 지워주는 카딱 스마트타올
# 1억기념 마지막앵콜ㅣ한 병 7,900원으로 엔진을 새것처럼 바꿔주는 마법
# [아마존평점 4.9점] 20년 악력기 장인이 만든 10년보증 악력기
# 작고 가벼워 편리한, 접이식 전기자전거 G바이크 미니
# 마사지는 문질러야 제맛. 물리치료사 10년 경력을 담은 마사지기 #스트릭
# 당신이 뭘 원하는지 다 아니까 - 스마트 후미등 Cliq
# 전세계가 열광하는 가상현실 라이딩! 게임처럼 재미있게 타는 야핏 사이클
# ...

# %%
pd_data = pd.DataFrame(sport, columns=['wadiz sport_mobility'])
pd_data
# Out:
#                          wadiz sport_mobility
# 0            세계최초의 폴딩형 역삼륜 전동킥보드 - TRANSBOARD
# 1         [글로벌 5억] 100년간 변하지 않은 와이퍼의 혁신ㅣ킴블레이드
# 2    튼튼한 고정력, 넉넉한 수납력에 무선충전까지! 차량용 클로버 멀티 컵홀더
# 3      [2억 앵콜] 100년간 변하지 않은 자동차 와이퍼의 혁신ㅣ킴블레이드
# 4           [1+1이벤트] 무게와 가격 부담을 동시에 잡은 전동킥보드!
# ..                                        ...
# 763                           가족에게 특별한 선물을 하다
# 764                 발이정말 편한 가죽소재 프리미엄급 롤러스케이트
# 765       강력한 풀파워모터 장착! 보관과 이동이 편리한 접이식 전기자전거
# 766           [맞춤제작] 이번 여름 맞춤제작 유니폼으로 시~원하게!!
# 767           누구나 쉽게 할 수 있는 다이어트, 홈트레이닝은 #굿트짐
#
# [768 rows x 1 columns]
