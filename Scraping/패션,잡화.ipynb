# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
import requests

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FEC4-11B6
#
#  C:\Develops 디렉터리
#
# 2021-08-12  오후 09:57        11,177,472 chromedriver.exe
#                1개 파일          11,177,472 바이트
#                0개 디렉터리  62,811,525,120 바이트 남음

# %%
driver = webdriver.Chrome()
driver.get('https://www.wadiz.kr/web/wreward/category/288?keyword=&endYn=Y&order=support')

# %%
num_scroll = 15
while num_scroll:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight-1000);")
    time.sleep(2)
    num_scroll -= 1
time.sleep(1)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

browser = webdriver.Chrome('./chromedriver.exe')
data_list = soup.select('div.ProjectCardList_list__1YBa2 > div > div > div > div')
fashion=[]
for data in data_list:
    title = data.select('strong')[0].text.strip()
    print(title)
    fashion.append([title])
# Out:
# 마진 0%! 백팩의 새로운 역사를 쓸 2만원대 백팩 [유닛백2]
# [1.8억 앵콜] 써 본 마스크 중 최고네요. 성능도 착용감도 저세상급
# [패션ㆍ잡화 역대 1위 펀딩] 99%를 위해 만들어진 1%의 램스킨 자켓
# 3000원의 행복! 한국자체개발 마스크스트랩 투명 마스크줄 Maskzul
# 마스크안에 시원한 바람이 불어요! 내 마스크 속 무동력 선풍기 '마풍기'
# 11년을 입을 수 있는 11색 무지티
# [마감임박] 2만원대 화제의 가성비갑 유닛백2 with 신상 트래블백
# 쉽게 벗겨지지 않는 렉시의 인생 덧신, 게다가 마성의 쿠션감!
# 마스크 혁명, '탄성 고정식 덴탈마스크 프레임, 에어리(Airy)'
# [하이테크 마스크] 꿈의 소재 그래핀으로 만든, 비교불가 마스크!
# [4009% 앵콜] 장마완벽대비! 반투명/검정 신발방수커버 블록웨일스
# 일회용 마스크에 에어밸브를 탈착 가능하다고~? 모든 마스크에~??
# [4만원대 프리미엄 캐리어] 12,649명이 인정한 갓성비! 유닛백3
# 써 본 마스크 중 최고네요. 성능도, 착용감도 저세상급<세컨드스킨마스크>
# [마지막 앵콜] 10만원 초반에 누리는 이탈리아 명품 스니커즈의 완벽함
# [인생패딩] 언제 어디서나 멋진 슬림한 구스다운 패딩
# [와디즈단독] 600억 판매, 3D분리팬티의 끝판왕 #라쉬반
# 라이더는 꼭 비싸야만 할까? 1%로 만들어진, 99%를 위한 램스킨 자켓
# 전통적인 여름 원단 삼베의 재탄생! 통풍이 잘 되는 <삼베 마스크>
# ♥1억앵콜♥ 발도 매트리스가 필요하다. 엣지있고 편안한 마성의 스니커즈!
# <카드 5장을 가장 얇게 보관하는 방법> 핸드폰 탈부착이 가능한 카드지갑
# 나를 위한 스포츠 마스크! 필터 교체형 올인원마스크
# 비싸다고 좋은 깔창아닙니다!적정한 가격으로 만나는 진짜 아치 서포트 깔창
# [3억펀딩] "마성의 인생 덧신"의 귀환, 벗을때까진 벗겨지지 않는다.
# 에어가 이 가격? 구름위를 걷는것 같은 편안함!! 에어 라텍스 스니커즈!
# ...

# %%
pd_data = pd.DataFrame(fashion, columns=['wadiz fashion_accessories'])
pd_data
# Out:
#                     wadiz fashion_accessories
# 0         마진 0%! 백팩의 새로운 역사를 쓸 2만원대 백팩 [유닛백2]
# 1     [1.8억 앵콜] 써 본 마스크 중 최고네요. 성능도 착용감도 저세상급
# 2    [패션ㆍ잡화 역대 1위 펀딩] 99%를 위해 만들어진 1%의 램스킨 자켓
# 3    3000원의 행복! 한국자체개발 마스크스트랩 투명 마스크줄 Maskzul
# 4    마스크안에 시원한 바람이 불어요! 내 마스크 속 무동력 선풍기 '마풍기'
# ..                                        ...
# 763     라면 먹을 때마다 앞이 안 보였다면? 김서림방지 안경닦이 <비비룩>
# 764   이제는 양면시대! 뒤집어 [보아] 자켓/코트, 10만원이면 충분합니다.
# 765    [4억, 8컬러, 3사이즈] 5만원대 천연소가죽 브리프케이스,앤트레스
# 766  [리코브]모든 노하우를 담아낸 모두가 입고싶고 어울리는 "모.두.팬.츠"
# 767                    패션 에디터들이 만든 유틸리티 레인 코트
#
# [768 rows x 1 columns]
