# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
import requests

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FEC4-11B6
#
#  C:\Develops 디렉터리
#
# 2021-08-12  오후 09:57        11,177,472 chromedriver.exe
#                1개 파일          11,177,472 바이트
#                0개 디렉터리  70,503,469,056 바이트 남음

# %%
driver = webdriver.Chrome()
driver.get('https://www.wadiz.kr/web/wreward/category/309?keyword=&endYn=Y&order=support')

# %%
num_scroll = 15
while num_scroll:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight-1000);")
    time.sleep(2)
    num_scroll -= 1
time.sleep(1)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

browser = webdriver.Chrome('./chromedriver.exe')
data_list = soup.select('div.ProjectCardList_list__1YBa2 > div > div > div > div')
baby=[]
for data in data_list:
    title = data.select('strong')[0].text.strip()
    print(title)
    baby.append([title])
# Out:
# 리니어블, 우리 아이들을 지켜 주는 스마트밴드
# 우리 아이와 함께 떠나는 특별한 여행, 달려라 코딩버스
# [와 뽀로로다!] 즐겁게 똑똑해지는 두뇌퍼즐! 블록이 살아 움직여요!
# 수험생의 필수품, 자동으로 지워지는 볼펜 화이트몽키펜
# [펀딩 마감] 아이들이 코딩을 좋아하는 이유, 달려라 코딩버스<미국편>
# [3차펀딩] 퇴근 후 1분! 아이에게 아빠를 선물하는 아빠놀이 백과사전
# 자기주도 이유식 필수 준비물, 안전한 우리아이 첫 과즙망
# 이유식부터 자기주도 유아식까지 안전하게~ 우리아이 실리콘 스푼/포크 세트
# 유아용품 아무데나 보관하지 마세요. 맘스비 안심 항균 파우치
# <봄배송> 마이크로필터로 '안심'외출! 한스펌킨 아기띠가드가 지켜줄게요.
# [700대 한정 리안 유모차] 디럭스급 안정감에 컴팩트한 폴딩까지
# cprCUBE-씨피알큐브: 온 가족을 위한 휴대용 심폐소생술 교육 키트
# [힌트] 해먹이 있는 플레이하우스
# 인공지능 캐릭터 로봇 <뽀로롯 미니>
# [5000%달성] 아직도 유모차를 모시고 다니시나요? 1초 폴딩 유모차
# 크로스백이 힙시트가 되는, 세상 신박한 꿀육아템 2in1 [본분 힙시트]
# [앵콜] 퇴근 후 1분! 아이에게 아빠를 선물하는 아빠놀이 백과사전
# 육아필수템! 우리말, 영어, 중국어로 말하는 우리집 실내놀이터 세이하우스
# 우리 가족 열날 땐 언제나 써모케어 스마트 체온계
# 아이와 집에서 놀기 만랩! 별자리와 함께 즐기는 뽀로로 별자리볼!
# 비트브릭 : 만지고, 배우고, 만드는 세상
# [해외 7억 펀딩 달성] 포브 유아용카시트의 새로운 패러다임을 제시하다.
# SMAKIZ : 아이들의 생애 첫번째 전동 스마트 데스크
# [인덕대] 아이들의 창의력을 키워주는 스마트한 블록놀이
# <여름전배송> 카시트&유모차에 쓰는 에어포켓2 쿨시트! 땀 걱정 NO!
# [미국엄마도 선택한 영어학습기] 우리 아이 취향저격 영어놀이 스퀘어판다
# [평점 4.8 앵콜] 미국엄마도 선택한 알파벳학습기 ! 우리아이 취향저격
# ...

# %%
pd_data = pd.DataFrame(baby, columns=['wadiz baby_kids'])
pd_data
# Out:
#                               wadiz baby_kids
# 0                   리니어블, 우리 아이들을 지켜 주는 스마트밴드
# 1              우리 아이와 함께 떠나는 특별한 여행, 달려라 코딩버스
# 2      [와 뽀로로다!] 즐겁게 똑똑해지는 두뇌퍼즐! 블록이 살아 움직여요!
# 3               수험생의 필수품, 자동으로 지워지는 볼펜 화이트몽키펜
# 4     [펀딩 마감] 아이들이 코딩을 좋아하는 이유, 달려라 코딩버스<미국편>
# ..                                        ...
# 422                       나의 첫 손뜨개 우리아이 겨울아이템
# 423              공간지각력+협응력=창의적인 조립 장난감 [밴드블록]
# 424             4 년 반(54개월)에 영어 4,000 문장 암기하기
# 425  나도 모르겠는 내 아이 심리상태, 15분만에 파악하기 ㅣ i-로그인 키트
# 426   유모차+카시트+요람, 이 모든 걸 하나로! | 올라운드 3in1 유모차
#
# [427 rows x 1 columns]
