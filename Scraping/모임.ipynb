# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
import requests

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FEC4-11B6
#
#  C:\Develops 디렉터리
#
# 2021-08-12  오후 09:57        11,177,472 chromedriver.exe
#                1개 파일          11,177,472 바이트
#                0개 디렉터리  73,414,021,120 바이트 남음

# %%
driver = webdriver.Chrome()
driver.get('https://www.wadiz.kr/web/wreward/category/313?keyword=&endYn=Y&order=support')

# %%
num_scroll = 15
while num_scroll:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight-1000);")
    time.sleep(2)
    num_scroll -= 1
time.sleep(1)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

browser = webdriver.Chrome('./chromedriver.exe')
data_list = soup.select('div.ProjectCardList_list__1YBa2 > div > div > div > div')
meeting=[]
for data in data_list:
    title = data.select('strong')[0].text.strip()
    print(title)
    meeting.append([title])
# Out:
# 완소균이부터 코스토리까지 과거의 경험, 미래의 도전을 공유합니다!
# 직장인의 딴짓을 돕는 멤버십커뮤니티, 딴짓클럽
# 똑똑! 혹시 '귀촌' 생각 여기있나요?
# 맥주로 만나는 새로운 경험! 비어스픽 프로그램 멤버십
# "육아는 누구나 처음이라" 양육자를 위한 커뮤니티 <123swing>
# 이런 소셜살롱 보셨나요?   영화테마살롱 -  컴'온무비
# 습관의 탄생 by 생각식당 개업 1주년 기념
# 나는 무엇을 좋아할까요? by 인문,예술 모임공간 CABINET
# 당신의 "퇴근후2시간",인사라운지에서 열리는 특별한 모임에 참여하세요!
# 언젠가 홀로 설 당신에게 보내는 "선택" 이야기 [가수 류세라]
# 100여명의 창작자들이 거쳐간 아티스트들을 위한 공간, 아트라우드
# 두어블, 40,50대를 위한 취미, 배움, 모임 플랫폼 개발 프로젝트
# [5.0점앵콜] 퇴직/이직 전 진짜 내가 하고 싶은 일을 찾는 곳ㅣ사하라
# 성찰이 필요할 때, 마음을 서예로 만나는 시간 [서예가 인중 이정화]
# 라이프쉐어 다이빙 클럽 - ME '나는 나를 얼마나 알고 있을까요?'
# 스트레스 [끊다] 익명 프리미엄 모임 / 3분기 시즌권 / 속시원하게풀자
# 라이프쉐어 다이빙 클럽 - TRAVEL '머무는 삶 vs 떠도는 삶'
# [시크릿사파리] 블랙뮤직과 춤을 사랑하는 2030의 신나는 연말파티!
# 스트라디움 GSML 서포터즈 모집
# 퇴직/이직 하기 전, 진짜 내가 하고 싶은 일을 찾는 곳 <사하라>
# [온라인앵콜]퇴사/이직/부업/투잡 전 진짜 내가 하고 싶은 일을 찾는 법
# (12명 정예  여성멤버 모집) 미국 부동산투자 여성사업가  변신프로젝트
# 라이프쉐어 다이빙클럽 - LOVE  '내 사랑은 왜 어려울까요?'
# 라이프쉐어 다이빙 클럽 - WORK '내게 맞는 일은 무엇일까요?'
# 떼구르르 보드게임여행
# [영화모임] 한 편의 영화 같은 3개월, 담화관 시즌모임으로 초대합니다!

# %%
pd_data = pd.DataFrame(meeting, columns=['wadiz meeting'])
pd_data
# Out:
#                                wadiz meeting
# 0       완소균이부터 코스토리까지 과거의 경험, 미래의 도전을 공유합니다!
# 1                  직장인의 딴짓을 돕는 멤버십커뮤니티, 딴짓클럽
# 2                      똑똑! 혹시 '귀촌' 생각 여기있나요?
# 3              맥주로 만나는 새로운 경험! 비어스픽 프로그램 멤버십
# 4     "육아는 누구나 처음이라" 양육자를 위한 커뮤니티 <123swing>
# 5            이런 소셜살롱 보셨나요?   영화테마살롱 -  컴'온무비
# 6                   습관의 탄생 by 생각식당 개업 1주년 기념
# 7        나는 무엇을 좋아할까요? by 인문,예술 모임공간 CABINET
# 8    당신의 "퇴근후2시간",인사라운지에서 열리는 특별한 모임에 참여하세요!
# 9        언젠가 홀로 설 당신에게 보내는 "선택" 이야기 [가수 류세라]
# 10      100여명의 창작자들이 거쳐간 아티스트들을 위한 공간, 아트라우드
# 11    두어블, 40,50대를 위한 취미, 배움, 모임 플랫폼 개발 프로젝트
# 12  [5.0점앵콜] 퇴직/이직 전 진짜 내가 하고 싶은 일을 찾는 곳ㅣ사하라
# 13    성찰이 필요할 때, 마음을 서예로 만나는 시간 [서예가 인중 이정화]
# 14    라이프쉐어 다이빙 클럽 - ME '나는 나를 얼마나 알고 있을까요?'
# 15  스트레스 [끊다] 익명 프리미엄 모임 / 3분기 시즌권 / 속시원하게풀자
# 16    라이프쉐어 다이빙 클럽 - TRAVEL '머무는 삶 vs 떠도는 삶'
# 17    [시크릿사파리] 블랙뮤직과 춤을 사랑하는 2030의 신나는 연말파티!
# 18                        스트라디움 GSML 서포터즈 모집
# 19     퇴직/이직 하기 전, 진짜 내가 하고 싶은 일을 찾는 곳 <사하라>
# 20  [온라인앵콜]퇴사/이직/부업/투잡 전 진짜 내가 하고 싶은 일을 찾는 법
# 21  (12명 정예  여성멤버 모집) 미국 부동산투자 여성사업가  변신프로젝트
# 22      라이프쉐어 다이빙클럽 - LOVE  '내 사랑은 왜 어려울까요?'
# 23     라이프쉐어 다이빙 클럽 - WORK '내게 맞는 일은 무엇일까요?'
# 24                               떼구르르 보드게임여행
# 25  [영화모임] 한 편의 영화 같은 3개월, 담화관 시즌모임으로 초대합니다!
