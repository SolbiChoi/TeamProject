# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
import requests

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FEC4-11B6
#
#  C:\Develops 디렉터리
#
# 2021-08-12  오후 09:57        11,177,472 chromedriver.exe
#                1개 파일          11,177,472 바이트
#                0개 디렉터리  73,485,197,312 바이트 남음

# %%
driver = webdriver.Chrome()
driver.get('https://www.wadiz.kr/web/wreward/category/290?keyword=&endYn=Y&order=support')

# %%
num_scroll = 15
while num_scroll:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight-1000);")
    time.sleep(2)
    num_scroll -= 1
time.sleep(1)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

browser = webdriver.Chrome('./chromedriver.exe')
data_list = soup.select('div.ProjectCardList_list__1YBa2 > div > div > div > div')
design=[]
for data in data_list:
    title = data.select('strong')[0].text.strip()
    print(title)
    design.append(title)
# Out:
# 가격마저 놀랍다! 디자이너 캐리어 & 백팩, 샤플 Dr.Nah
# 앵콜! 크로스백이 분리되는 다기능 여행 백팩. 트래블러스 하이
# [롤링 샤프] "손이 베지 않는, 안전한 칼"
# [3억 앵콜] 가장 아름다운 한국을 디자인하다, 세종여권케이스
# 나의 일상 속 두근두근, 향기나는 ‘디즈니_미니램프’
# 예쁘기만 한 줄 알았더니 '공기정화+악취제거' 만능이네? [큐어스톤]
# 바그람 팩: 오피스/ 짐(GYM)/ 여행 백팩 : 3-bags-in-1
# [4차앵콜]휴대용 안경닦이 포켓클리너! 어디에서나 가볍고 심플하게
# 평생 쓸 수 있는 잉크리스 펜! 연필 감성 ZAI Pencil
# 캄보디아에 학교를 짓는 딜럽 가죽팔찌
# 1만원대로 누리는 고급 힐링 | 순수 나무 인센스, 집에서 자연을 만나다
# 가볍게 접어 내 가방에 쏙! 휴대용 멀티독서대, G스탠드
# [5108% 앵콜] 큐어스톤, 모든공간 인테리어+악취제거를 한번에 해결!
# 뉴밍TV와 Let's play soap!
# 그림을 즐기는 가장 쿨한 방법, Monthly Artwork 핀즐
# 커피의 눈물이 주는 최고의 선물 TOC [톡]
# 내 주머니 속 안경닦이, 스윗포켓클리너
# FairY -TaLE : 동화 속 사랑의 디퓨져
# 여행배낭의 궁극체. [타우 백팩]
# [도전! 하루2리터] 하루 수분 섭취를 시간별로 달성하는 2L물병
# 노숙인들의 희망을 담아 콘삭스가 만드는 『STAND UP』 양말
# 언제 어디서든 내 마음을 볼 수 있도록 도와주는 마음보기연습앱, 마보!
# [꽃 정기구독] 오늘도 특별한 당신을 위해, 플라낭
# 인생은 꼬여도 이어폰은 꼬이지 않는다! 이어폰 정리는 요녀석
# 특별한 크리스마스 선물, 크래빌리로
# 국내최초 아기판다ㅣ이모삼촌들, 제가 왔어요! 에버랜드 <푸바오> 실사인형
# 가장 한국적인 자개, 여권케이스에 입다 <자개 투명 여권케이스>
# 피로 가득한 직장인을 위한 소소한 선물!!
# [소소문구] 우리가 찾던 6공 다이어리, 하프 다이어리 시즌 II
# ...

# %%
pd_data = pd.DataFrame(design, columns=['wadiz design_home accessories'])
pd_data
# Out:
#                wadiz design_home accessories
# 0         가격마저 놀랍다! 디자이너 캐리어 & 백팩, 샤플 Dr.Nah
# 1         앵콜! 크로스백이 분리되는 다기능 여행 백팩. 트래블러스 하이
# 2                  [롤링 샤프] "손이 베지 않는, 안전한 칼"
# 3         [3억 앵콜] 가장 아름다운 한국을 디자인하다, 세종여권케이스
# 4              나의 일상 속 두근두근, 향기나는 ‘디즈니_미니램프’
# ..                                       ...
# 763                클래식하고 유니크한 베지터블 레더 파우치&필통
# 764                   스타트업 디자인 환경 개선을 위한 첫걸음
# 765         '나' 전문가로 만들어주는 <나로쓰기 GUIDE&NOTE>
# 766        반지링, 모든 종이를 원하는 노트로 만들 수 있는 절대 반지
# 767  입맛대로 조합하는 모듈형 카메라가방, 풀그레인 가죽으로 소재까지 잡았다
#
# [768 rows x 1 columns]
