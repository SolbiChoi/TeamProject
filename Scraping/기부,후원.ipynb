# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
import requests

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FEC4-11B6
#
#  C:\Develops 디렉터리
#
# 2021-08-12  오후 09:57        11,177,472 chromedriver.exe
#                1개 파일          11,177,472 바이트
#                0개 디렉터리  73,568,362,496 바이트 남음

# %%
driver = webdriver.Chrome()
driver.get('https://www.wadiz.kr/web/wreward/category/312?keyword=&endYn=Y&order=support')

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

browser = webdriver.Chrome('./chromedriver.exe')
data_list = soup.select('div.ProjectCardList_list__1YBa2 > div > div > div > div')
donation=[]
for data in data_list:
    title = data.select('strong')[0].text.strip()
    print(title)
    donation.append([title])
# Out:
# 눈 감고도 크리에이터 되기!
# 수익금 100%기부) 평생 입을 수 있는 옷으로 기부까지!!????
# 사이클선수 민혜가 다시 일어설 수 있도록 희망을 선물해 주세요.
# 수해 피해입은 어려운 이웃에게 따뜻한 한끼를 보내주세요
# 작은 빛에서 희망의 출발로
# [포항 지진 이재민분들의 이야기] 우리, 아직 여기 있어요
# LOW, 아이들의 벽에 사랑을 그립니다.
# <입양지원키트> 지원 굿즈
# [백기완 X 신동일] 순수 우리말을 담은 새로운 형식의 창작음악극
# 난방소외가구에 따뜻한 밤을 선물할 초간편 난방텐트
# 당신의 가족이 군대에 있습니까? 그럼, 행복밀당스티커를 보내주세요
# 예술을 곁에두다 , 아트 X 수건
# 흐로닝언 유학생 박현후인턴 한국음식 보내기 프로젝트
# 위안부 구술집 일본어판 “우리 힘으로 만듭시다”
# '위안부'피해 할머니를 위한 나눔 라이딩
# 해맑게 웃어줘 : 라오스 아이들의 환한 미소를 지켜주세요
# 파란바지의 의인 김동수씨를 기억하시나요?
# [네팔 긴급구호]STAY STRONG NEPAL
# 북동인도 민스카 마을의 희망 Festival을 만들어주세요
# 결혼을 앞둔 부소대장님을 위한 전역한 소대원들의 선물
# 전기차 타보러 갈래요?
# 희망찬 대한민국을 위한 청소년 리더십, 제 11회 전국고교학생회장 토론회 및 리더십연수
# 장종택 전도사님의 둘째 딸, 온유의 회복을 기원하며...
# 에티오피아 친구의 간이식수술을 도와주세요.
# 작은숙녀 '샤론이'를 일으켜주세요
# 15년 3월 21일, 광화문에서 열리는 문화 교류의 장 '글로벌 빌리지'
# 우간다 에이즈 고아프로젝트
# 고아청년의 대학등록금모금하기
# 세월호 1주기, 학교 친구들이 세월호를 잊지 않기를 바라는 고3입니다.
# 청소년 백패킹! “나를 찾는 여행”을 준비합니다!
# 엘리베이터에서의 어색한 침묵을 깨자, 인사말 풍선 캠페인
# 재주소녀가 꿈을 향해 도전을 할 수 있도록 응원해주세요!!
# [네팔 긴급구호] 한순간 무너진 네팔 카트만두
# 왜 문화공간은 서울에만 있나요?
# 잊는다는 것은 잃는다는 것이다
# 전자오락 수호대를 모집합니다! - 서촌에서 가장 오래된 오락실 되살리기
# 백바울 선생님께 드리는 감사와 응원 메시지 릴레이
# 잠비아 소년 '루푸타의 꿈을 이뤄주세요.'
# 세월호 의인 '김홍경'씨를 위한 치료비 모금
# 빠진만큼 채운다.
# 대학언론의 새로운 시작을 위한 대학언론 세미나 'Re-'를 준비합니다

# %%
pd_data = pd.DataFrame(donation, columns=['wadiz donation_support'])
pd_data
# Out:
#                               wadiz donation_support
# 0                                    눈 감고도 크리에이터 되기!
# 1              수익금 100%기부) 평생 입을 수 있는 옷으로 기부까지!!????
# 2                사이클선수 민혜가 다시 일어설 수 있도록 희망을 선물해 주세요.
# 3                     수해 피해입은 어려운 이웃에게 따뜻한 한끼를 보내주세요
# 4                                     작은 빛에서 희망의 출발로
# 5                   [포항 지진 이재민분들의 이야기] 우리, 아직 여기 있어요
# 6                             LOW, 아이들의 벽에 사랑을 그립니다.
# 7                                     <입양지원키트> 지원 굿즈
# 8               [백기완 X 신동일] 순수 우리말을 담은 새로운 형식의 창작음악극
# 9                        난방소외가구에 따뜻한 밤을 선물할 초간편 난방텐트
# 10              당신의 가족이 군대에 있습니까? 그럼, 행복밀당스티커를 보내주세요
# 11                                예술을 곁에두다 , 아트 X 수건
# 12                      흐로닝언 유학생 박현후인턴 한국음식 보내기 프로젝트
# 13                        위안부 구술집 일본어판 “우리 힘으로 만듭시다”
# 14                            '위안부'피해 할머니를 위한 나눔 라이딩
# 15                   해맑게 웃어줘 : 라오스 아이들의 환한 미소를 지켜주세요
# 16                            파란바지의 의인 김동수씨를 기억하시나요?
# 17                        [네팔 긴급구호]STAY STRONG NEPAL
# 18                  북동인도 민스카 마을의 희망 Festival을 만들어주세요
# 19                     결혼을 앞둔 부소대장님을 위한 전역한 소대원들의 선물
# 20                                      전기차 타보러 갈래요?
# 21  희망찬 대한민국을 위한 청소년 리더십, 제 11회 전국고교학생회장 토론회 및 리더십연수
# 22                   장종택 전도사님의 둘째 딸, 온유의 회복을 기원하며...
# 23                           에티오피아 친구의 간이식수술을 도와주세요.
# 24                                작은숙녀 '샤론이'를 일으켜주세요
# 25          15년 3월 21일, 광화문에서 열리는 문화 교류의 장 '글로벌 빌리지'
# 26                                    우간다 에이즈 고아프로젝트
# 27                                   고아청년의 대학등록금모금하기
# 28           세월호 1주기, 학교 친구들이 세월호를 잊지 않기를 바라는 고3입니다.
# 29                       청소년 백패킹! “나를 찾는 여행”을 준비합니다!
# 30                   엘리베이터에서의 어색한 침묵을 깨자, 인사말 풍선 캠페인
# 31                  재주소녀가 꿈을 향해 도전을 할 수 있도록 응원해주세요!!
# 32                         [네팔 긴급구호] 한순간 무너진 네팔 카트만두
# 33                                 왜 문화공간은 서울에만 있나요?
# 34                                  잊는다는 것은 잃는다는 것이다
# 35           전자오락 수호대를 모집합니다! - 서촌에서 가장 오래된 오락실 되살리기
# 36                       백바울 선생님께 드리는 감사와 응원 메시지 릴레이
# 37                           잠비아 소년 '루푸타의 꿈을 이뤄주세요.'
# 38                          세월호 의인 '김홍경'씨를 위한 치료비 모금
# 39                                         빠진만큼 채운다.
# 40            대학언론의 새로운 시작을 위한 대학언론 세미나 'Re-'를 준비합니다
