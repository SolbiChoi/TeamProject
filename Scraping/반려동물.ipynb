# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
import requests

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FEC4-11B6
#
#  C:\Develops 디렉터리
#
# 2021-08-12  오후 09:57        11,177,472 chromedriver.exe
#                1개 파일          11,177,472 바이트
#                0개 디렉터리  71,685,799,936 바이트 남음

# %%
driver = webdriver.Chrome()
driver.get('https://www.wadiz.kr/web/wreward/category/308?keyword=&endYn=Y&order=support')

# %%
num_scroll = 15
while num_scroll:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight-1000);")
    time.sleep(2)
    num_scroll -= 1
time.sleep(1)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

browser = webdriver.Chrome('./chromedriver.exe')
data_list = soup.select('div.ProjectCardList_list__1YBa2 > div > div > div > div')
pet=[]
for data in data_list:
    title = data.select('strong')[0].text.strip()
    print(title)
    pet.append([title])
# Out:
# 반려동물의 건강과 멘탈 케어를! '바램 펫 피트니스 로봇'
# 빛을 담은 반려동물 정수기 - 두잇 워터팟
# [하루 3분] 한 손으로 끝내는 고양이 양치질, 츄잉브러쉬
# 혈관을 보며 자르는 강아지,고양이 발톱깎이 - 룩컷 (Lookut)
# 우리 아이를 혼자 두지 마세요. 반려동물용 인공지능로봇 [고미볼]
# 고양이와 댕댕이들의 국민식기! '달빛식기' 뭐가 달라서?!
# ⭐댕냥이 시선강탈⭐ 자동으로 움직이는 피트니스 로봇
# [미국 특허] 지독한 댕냥이 입냄새! 간편하게 관리할 순 없을까?
# ⭐11억 글로벌 펀딩⭐ 세계 열풍 미션 펫토이, 위키드볼
# 낚싯대처럼 놀아주면 치아 관리 끝! 고양이 맞춤 덴탈껌 [와이어츄]
# <1억펀딩>댕냥이 발톱깎이가 이렇게 쉬웠나요? 더 새로워진 NEW 룩컷
# [견생템] 많이 싸도 괜찮아~하루 한장 욜로홀로 배변패드
# 우리 냥이를 위한 캣폴 대중화 프로젝트 - 톡톡팩토리
# 고양이의 개인 공간! 가또블랑코의 신소재 하이엔드 캣폴
# 팝펫 드라이룸_일상의 가치를 + 더한 펫드라이룸을 소개합니다.
# [퍼시터 롤링팡]너~무 쉬워, 댕냥이도 발로하는 자존감 찾기
# 세계 최초 고양이 알로그루밍 브러시 쓰담이!
# 배변패드의 불편함을 없애고 싶었던 신입사원이 만들었습니다! [감동패드]
# 펫드라이기의 끝판왕! 우리집 댕댕이도 쓰고, 나도 쓰는 활용도만렙 두즈!
# 강집사 초대형 고양이 화장실 + 멀티박스!! 냥이와 집사를 위한 선택
# 캣휠도 가구다! 공간에 녹아드는 조용한 캣휠 _ 브라운즈 캣휠
# [기도압박 NO] H형 하네스에 밴드를 입히다, 충격완화 하네스 핏밴드
# 본질의 범위를 넓힌 고양이 정수기, 펫맘 워터.
# [5981% 앵콜펀딩] 견생템 많이 싸도 괜찮아~하루한장 욜로홀로배변패드
# 골골송 제조기! 고양이 알로그루밍 브러시 '일루'
# 사랑하는 반려동물의 건강, 집에서 터치 한 번으로 확인하세요!
# 댕댕이 치석관리 언제까지 미루실 건가요? <펫즐>로 매일 맛있'개'!
# ...

# %%
pd_data = pd.DataFrame(pet, columns=['wadiz pet'])
pd_data
# Out:
#                                     wadiz pet
# 0            반려동물의 건강과 멘탈 케어를! '바램 펫 피트니스 로봇'
# 1                     빛을 담은 반려동물 정수기 - 두잇 워터팟
# 2            [하루 3분] 한 손으로 끝내는 고양이 양치질, 츄잉브러쉬
# 3       혈관을 보며 자르는 강아지,고양이 발톱깎이 - 룩컷 (Lookut)
# 4        우리 아이를 혼자 두지 마세요. 반려동물용 인공지능로봇 [고미볼]
# ..                                        ...
# 763                간편하지만 실용적인 손목형 산책가방 <펫코백!>
# 764         물 안마시는 고양이, 밥 안먹는 강아지를 위한 보양식 #온기
# 765                     첫 고양이를 위한 다 갖춘 놀이터 캣섬
# 766  오래오래 주인님과 함께하고 싶어요_[한미특허] 반려동물 영양제 오구오구멍
# 767     더운 여름 음수량 늘리기 프로젝트 [오오 펫워터볼 + 냥멍건강수첩]
#
# [768 rows x 1 columns]
