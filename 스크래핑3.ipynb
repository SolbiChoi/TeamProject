# %% [markdown]
# <a href="https://colab.research.google.com/github/SolbiChoi/TeamProject/blob/master/%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%913.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from selenium import webdriver
import time
import requests

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FEC4-11B6
#
#  C:\Develops\learn_webscraping 디렉터리
#
# 2021-06-25  오전 09:47        11,107,328 chromedriver.exe
#                1개 파일          11,107,328 바이트
#                0개 디렉터리  77,167,878,144 바이트 남음

# %%
browser = webdriver.Chrome('./chromedriver.exe')

# %%
browser.get('https://www.wadiz.kr/web/wreward/main?keyword=&endYn=Y&order=support')

# %%
prev_height = browser.execute_script("return document.body.scrollHeight")

while True:
    browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    
    time.sleep(2)
    
    curr_height = browser.execute_script("return document.body.scrollHeight")
    
    if(curr_height == prev_height):
        break
    else:
        prev_height = browser.execute_script("return document.body.scrollHeight")

# %%
html=browser.page_source

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html,'html.parser')

# %%
contents = soup.select('div[class^=RewardProjectListApp]')
print(type(contents))
contents[0]
# Out:
# <class 'bs4.element.ResultSet'>
# <div class="RewardProjectListApp_container__1ZYeD"><div class="ProjectListHead_container__rpQ37 RewardProjectListHead_container__2FzIj"><div class="ProjectListHead_bar__2dyHz"><h3 class="ProjectListHead_title__2pv8I">전체보기</h3><form class="ProjectListHead_search__HN3am"><label for="search-keyword-ad919d47-d769-4008-a7e9-f06f25d97a5c"><input class="" id="search-keyword-ad919d47-d769-4008-a7e9-f06f25d97a5c" placeholder="검색" type="search" value=""/><div class="ProjectListHead_right__3_Jo1"><button aria-label="검색" class="ProjectListHead_find__3HsFc" type="submit"><i class="icon search"></i></button></div></label></form><div class="SortingSelect_container__3voSC ProjectListHead_sorting__2n1WY RewardProjectListHead_fundingSorting__2n0MF">종료된<i aria-hidden="true" class="icon expand-more SortingSelect_icon__khE3_"></i><select class="SortingSelect_select__23ANT" name="status"><option value="ALL">전체</option><option value="N">진행중</option><option value="Y">종료된</option></select></div><div class="SortingSelect_container__3voSC ProjectListHead_sorting__2n1WY">응원참여자순<i aria-hidden="true" class="icon expand-more SortingSelect_icon__khE3_"></i><select class="SortingSelect_select__23ANT" name="order"><option value="recommend">추천순</option><option value="popular">인기순</option><option value="amount">펀딩액순</option><option value="closing">마감임박순</option><option value="recent">최신순</option><option value="support">응원참여자순</option></select></div><div class="ProjectListHead_children__2Y7-F"></div><button class="ProjectListHead_cardType__2_YL4"></button></div><div class="ProjectListHead_children__2Y7-F"></div></div><div class="ProjectCardList_container__3Y14k"><div class="ProjectCardList_list__1YBa2"><div class="ProjectCardList_item__1owJa"><div><div class="CommonCard_container__e_ebQ CommonCard_squareSmall__1Cdkn"><a aria-hidden="true" class="CardLink_link__1k83H CommonCard_image__vaqkf" href="https://www.wadiz.kr/web/campaign/detail/118015?acid=10010025&amp;_refer_section_st=REWARD_0" tabindex="-1"><div class="CommonCard_rect__2wpm4"><span class="CommonCard_background__3toTR" style=""></span><div class="banner_adBadge__2iyux">AD</div></div></a><div class="CommonCard_info__1f4kq"><div class="RewardProjectCard_info__3JFub"><div class="RewardProjectCard_infoTop__3QR5w"><a class="CardLink_link__1k83H" href="https://www.wadiz.kr/web/campaign/detail/118015?acid=10010025&amp;_refer_section_st=REWARD_0"><p class="CommonCard_title__1oKJY RewardProjectCard_title__iUtvs"><strong>[진짜 이탈리안이 뭉쳤다] 알베르토 X 셰프의 세상에 없던 가지 간편식</strong></p></a><div><span class="RewardProjectCard_category__2muXk">푸드</span><span class="RewardProjectCard_makerName__2q4oH">주식회사 근본</span></div></div><div class="RewardProjectCard_gauge__3p9US"><span style="width: 100%;"></span></div><span class="RewardProjectCard_percent__3TW4_">2040%</span><span class="RewardProjectCard_amount__2AyJF">20,404,000원</span><span class="RewardProjectCard_days__3eece RewardProjectCard_isAchieve__1LcUu"><span class="RewardProjectCard_remainingDay__2TqyN">14일</span><span class="RewardProjectCard_remainingDayText__2sRLV">남음</span><span class="RewardProjectCard_isAchieve__1LcUu"></span></span></div></div></div></div></div><div class="ProjectCardList_item__1owJa"><div><div class="CommonCard_container__e_ebQ CommonCard_squareSmall__1Cdkn"><a aria-hidden="true" class="CardLink_link__1k83H CommonCard_image__vaqkf" href="/web/campaign/detail/65295" tabindex="-1"><div class="CommonCard_rect__2wpm4"><span class="CommonCard_background__3toTR" style=""></span></div></a><div class="CommonCard_info__1f4kq"><div class="RewardProjectCard_info__3JFub"><div class="RewardProjectCard_infoTop__3QR5w"><a class="CardLink_link__1k83H" href="/web/campaign/detail/65295"><p class="CommonCard_title__1oKJY RewardProjectCard_title__iUtvs"><strong>[글로벌 최초 펀딩] 스마트워치가 3만원대? 가성비 끝판왕! 헬로우 솔라</strong></p></a><div><span class="RewardProjectCard_category__2muXk">테크·가전</span><span class="RewardProjectCard_makerName__2q4oH">주식회사 위즈굿</span></div></div><div class="R ...

# %%
title =soup.select('strong')
title
# Out:
# [<strong>[진짜 이탈리안이 뭉쳤다] 알베르토 X 셰프의 세상에 없던 가지 간편식</strong>,
#  <strong>[글로벌 최초 펀딩] 스마트워치가 3만원대? 가성비 끝판왕! 헬로우 솔라</strong>,
#  <strong>아이즈원 리런칭을 위한 작은 한 걸음, 평행우주 프로젝트</strong>,
#  <strong>[마지막 앵콜/3억] 외출필수품! 111g UV차단 초경량우산(1만원대)</strong>,
#  <strong>무선충전기의 영역을 넘었다, 카딱 스마트 무선고속충전기</strong>,
#  <strong>음악이 들리는 선글라스 정글 팬써</strong>,
#  <strong>[2억신화/평점4.9앵콜] 미친발색 글리터 섀도우 #화이트 스완</strong>,
#  <strong>마진 0%! 백팩의 새로운 역사를 쓸 2만원대 백팩 [유닛백2]</strong>,
#  <strong>[PaMu] 글로벌 10억 펀딩! 세계가 인정한 Hi-Fi 파뮤 이어폰</strong>,
#  <strong>[8천명이 서포터한 앵콜펀딩] 양치만으로 치아를 하얗게 쭉~ 블링2치약</strong>,
#  <strong>더지니어스 흑과백, 보드게임으로 재탄생! 쉽고 빠르지만 가슴쫄깃한 구룡투</strong>,
#  <strong>유.무선 이어폰 장점을 결합한 하이브리드 무선이어폰 PaMu Slide</strong>,
#  <strong>[마지막앵콜] 끈적임 없는 순삭 흡수 참마크림 I 81%진정, 착한비건</strong>,
#  <strong>[3만원대 무선 핸디형청소기] 자취방.사무실.자동차 "청소가 쉬워져요"</strong>,
#  <strong>[아웃핏터] 손 안대고 다림질과 건조를 동시에? 세상에 없던 의류관리기!</strong>,
#  <strong>반려동물의 건강과 멘탈 케어를! '바램 펫 피트니스 로봇'</strong>,
#  <strong>가격마저 놀랍다! 디자이너 캐리어 &amp; 백팩, 샤플 Dr.Nah</strong>,
#  <strong>범인은 이 안에 있어!당신의 추리 본능을 깨울 보드게임 &lt;서스펙트 게임&gt;</strong>,
#  <strong>[모슈] 장시간 보온보냉! 넘어져도 새지 않는 실리콘 스트로우 텀블러</strong>,
#  <strong>소녀를 기억하는 방법. 위안부 소녀상 세우기 캠페인</strong>,
#  <strong>초음파 세척기 아직 모르시나요? 세균 제거 99.7%오염 완벽 세척!</strong>,
#  <strong>[링티 복숭아] 군의관들의 링거워터가 신제품으로 돌아왔습니다!</strong>,
#  <strong>[1억 앵콜] 드럼? 게임하듯 쉽게 따라하세요, 어느덧 나도 드럼고수!</strong>,
#  <strong>[글로벌 45억 펀딩] 전 세계가 열광한 모바일 컬러프린터 '프린큐브'</strong>,
#  <strong>세계최초의 폴딩형 역삼륜 전동킥보드 - TRANSBOARD</strong>,
#  <strong>♠남다름의 띵작♠ 가장 완벽한 Ai 자동 무선 충전 거치대</strong>,
#  <strong>베이직북14 : 대기업 노트북과 비교해보세요, 20만원대 파격 울트라북!</strong>,
#  <strong>[천재가 설계한] 일본에선 없어서 못판다는 등골산뜻 쿨매트</strong>,
#  <strong>[영주시]당뇨먹는 돼지감자(뚱딴지) 관사골을 부탁해^^</strong>,
#  <strong>폰카도 고퀄로 만들어버리는 요술봉, 에버스틱</strong>,
#  <strong>[킬리X여행에미치다] 청춘들을 위한 리얼 여행배낭 제작 프로젝트</strong>,
#  <strong>비긴어게인 영철버거 프로젝트</strong>,
#  <strong>추억을 담는 7 in 1 촬영 디바이스 : 셀디</strong>,
#  <strong>흡연자를 위한 혁신적인 재떨이혁명. 카딱 스마트재떨이</strong>,
#  <strong>Perfume Teller로 찾는 나만의 향기 - 파펨</strong>,
#  <strong>불편하셨죠? 이젠 편하고 안전하게 보면서 직접 관리하세요 이어팝 으로 </strong>,
#  <strong>유기견보호소 &lt;내사랑바둑이&gt;의 철거와 이사 이야기</strong>,
#  <strong>기능성 베개가 이 가격? 50만개 라텍스 후레이크로 만든 [우유베개]</strong>,
#  <strong> [1.8억 앵콜] 써 본 마스크 중 최고네요. 성능도 착용감도 저세상급</strong>,
#  <strong>식사의 새로운 패러다임! 마시는 액상형 식사, 밀스 드링크</strong>,
#  <strong>[패션ㆍ잡화 역대 1위 펀딩] 99%를 위해 만들어진 1%의 램스킨 자켓</strong>,
#  <strong>3000원의 행복! 한국자체개발 마스크스트랩 투명 마스크줄 Maskzul</strong>,
#  <strong>[만족도 1위 선풍기] 아직도 들고 다녀? "땀쟁이 필수템" 넥밴드선풍기</strong>,
#  <strong>[글로벌 5억] 100년간 변하지 않은 와이퍼의 혁신ㅣ킴블레이드</strong>,
#  <strong>변기 오염/세균/물때, 물내림으로 청소 끝! 이제, 변기청소 간편하게</strong>,
#  <strong>37억 펀딩! Hi-Fi 무선충전 블루투스 이어폰 '파뮤스크롤'</strong>,
#  <strong>튼튼한 고정력, 넉넉한 수납력에 무선충전까지! 차량용 클로버 멀티 컵홀더</strong>,
#  <strong>18시간 보냉되는 알렉스텀블러, 여름에도 ALEX와 함께하세요!</strong>]

# %%
len(title), type(title)
# Out:
# (48, bs4.element.ResultSet)

# %%
#product=content.select('p.commomCard-title')[0]
#product

# %%
#title[0].text.strip()

# %%
#shop = [] # or list()
#for i in contents:
    #title = contents.select('div[class^=RewardProjectListApp]')[0]
    #shop.append([title.text.strip()])
